# %%
from bs4 import BeautifulSoup
# from lxml import etree
import pandas as pd
import requests
import re
from tqdm import tqdm
import pickle

# %%
site_url = 'https://en.wikipedia.org'
base_url = 'https://en.wikipedia.org/wiki/Category:'

# %%
def get_song_pages(year, year_subpage_url):
    song_pages = {}

    url = year_subpage_url

    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    song_columns = soup.find_all('div', {'class': 'mw-category-group'})

    for c in song_columns:
        try:
            if c.find('h3').text >= list(song_pages)[-1][0]: # minimize redundant retrieval
                song_urls = c.find_all('a', href=True)
                for u in song_urls:
                    song_pages[u.text] = (f"{site_url}{u['href']}", year)

        except:
            song_urls = c.find_all('a', href=True)
            for u in song_urls:
                song_pages[u.text] = (f"{site_url}{u['href']}", year)

    return song_pages

# %%
def get_year_subpages(year_page_url):
    year_subpages = {}
    url = year_page_url

    page = requests.get(url)
    soup = BeautifulSoup(page.content, 'html.parser')
    toc = soup.find('div', {'id': 'toc'})

    try:
        subpage_div = toc.find_all('li')[-1]
    except:
        subpage_div = toc.find('div', {'class': 'large-cat-toc-body'})

    subpage_urls = subpage_div.find_all('a', href=True)
    for u in subpage_urls:
        year_subpages[u.text] = u['href']

    return year_subpages

# %%
def get_year_pages(first_decade, last_decade):
    pattern = re.compile('\d{4} songs')

    year_pages = {}

    for decade in range(first_decade, last_decade + 10, 10):
        endpoint = f'{decade}s_songs'
        page = requests.get(f'{base_url}{endpoint}')
        soup = BeautifulSoup(page.content, 'html.parser')
        categories = soup.find_all('div', {'class': 'mw-category mw-category-columns'})
        for c in categories:
            urls = c.find_all('a', href=True)
            for u in urls:
                if bool(pattern.match(u.text)):
                    year_pages[u.text.split()[0]] = f"{site_url}{u['href']}"

    return year_pages

# %%
songs_for_year = {}
songs_by_year = []

years = get_year_pages(1950,2010)
for year, y_url in tqdm(years.items()): 
    print('Year:',year)
    subpages = get_year_subpages(y_url)
    for subpage, s_url in tqdm(subpages.items()):
        songs = get_song_pages(year, s_url)
        songs_for_year = songs_for_year | songs
    
    song_list = [(k, v[0], v[1]) for k,v in songs_for_year.items()]
    songs_by_year.extend(song_list)

    print(f'Songs Collected: {len(songs_by_year)}')
    
with open('wiki_songs.pickle', 'wb') as handle:
    pickle.dump(songs_by_year, handle)
    
songs_by_year
# Out:
#   0%|          | 0/70 [00:00<?, ?it/s]
# Year: 1950
# 100%|██████████| 26/26 [00:04<00:00,  5.32it/s]
#   1%|▏         | 1/70 [00:05<05:51,  5.09s/it]
# Songs Collected: 135
# Year: 1951
# 100%|██████████| 26/26 [00:05<00:00,  4.76it/s]
#   3%|▎         | 2/70 [00:10<06:10,  5.44s/it]
# Songs Collected: 417
# Year: 1952
# 100%|██████████| 26/26 [00:05<00:00,  4.67it/s]
#   4%|▍         | 3/70 [00:16<06:14,  5.60s/it]
# Songs Collected: 847
# Year: 1953
# 100%|██████████| 26/26 [00:06<00:00,  4.07it/s]
#   6%|▌         | 4/70 [00:23<06:36,  6.00s/it]
# Songs Collected: 1421
# Year: 1954
# 100%|██████████| 26/26 [00:06<00:00,  3.91it/s]
#   7%|▋         | 5/70 [00:30<06:50,  6.32s/it]
# Songs Collected: 2146
# Year: 1955
# 100%|██████████| 26/26 [00:06<00:00,  3.94it/s]
#   9%|▊         | 6/70 [00:36<06:55,  6.49s/it]
# Songs Collected: 3036
# Year: 1956
# 100%|██████████| 26/26 [00:07<00:00,  3.46it/s]
#  10%|█         | 7/70 [00:44<07:14,  6.90s/it]
# Songs Collected: 4187
# Year: 1957
# 100%|██████████| 26/26 [00:06<00:00,  3.92it/s]
#  11%|█▏        | 8/70 [00:51<07:07,  6.90s/it]
# Songs Collected: 5597
# Year: 1958
# 100%|██████████| 26/26 [00:07<00:00,  3.67it/s]
#  13%|█▎        | 9/70 [00:58<07:08,  7.03s/it]
# Songs Collected: 7312
# Year: 1959
# 100%|██████████| 26/26 [00:07<00:00,  3.50it/s]
#  14%|█▍        | 10/70 [01:06<07:13,  7.23s/it]
# Songs Collected: 9354
# Year: 1960
# 100%|██████████| 26/26 [00:07<00:00,  3.59it/s]
#  16%|█▌        | 11/70 [01:14<07:11,  7.31s/it]
# Songs Collected: 11702
# Year: 1961
# 100%|██████████| 26/26 [00:06<00:00,  3.87it/s]
#  17%|█▋        | 12/70 [01:20<06:57,  7.20s/it]
# Songs Collected: 14407
# Year: 1962
# 100%|██████████| 26/26 [00:07<00:00,  3.64it/s]
#  19%|█▊        | 13/70 [01:28<06:53,  7.25s/it]
# Songs Collected: 17517
# Year: 1963
# 100%|██████████| 26/26 [00:06<00:00,  3.90it/s]
#  20%|██        | 14/70 [01:35<06:40,  7.15s/it]
# Songs Collected: 21063
# Year: 1964
# 100%|██████████| 26/26 [00:07<00:00,  3.57it/s]
#  21%|██▏       | 15/70 [01:42<06:39,  7.26s/it]
# Songs Collected: 25146
# Year: 1965
# 100%|██████████| 26/26 [00:06<00:00,  3.85it/s]
#  23%|██▎       | 16/70 [01:49<06:27,  7.18s/it]
# Songs Collected: 29800
# Year: 1966
# 100%|██████████| 26/26 [00:07<00:00,  3.57it/s]
#  24%|██▍       | 17/70 [01:57<06:26,  7.28s/it]
# Songs Collected: 35100
# Year: 1967
# 100%|██████████| 26/26 [00:06<00:00,  3.81it/s]
#  26%|██▌       | 18/70 [02:04<06:15,  7.21s/it]
# Songs Collected: 41213
# Year: 1968
# 100%|██████████| 26/26 [00:07<00:00,  3.64it/s]
#  27%|██▋       | 19/70 [02:11<06:10,  7.26s/it]
# Songs Collected: 48082
# Year: 1969
# 100%|██████████| 26/26 [00:06<00:00,  3.84it/s]
#  29%|██▊       | 20/70 [02:18<05:59,  7.18s/it]
# Songs Collected: 55745
# Year: 1970
# 100%|██████████| 26/26 [00:07<00:00,  3.60it/s]
#  30%|███       | 21/70 [02:26<05:55,  7.26s/it]
# Songs Collected: 64221
# Year: 1971
# 100%|██████████| 26/26 [00:07<00:00,  3.55it/s]
#  31%|███▏      | 22/70 [02:33<05:52,  7.35s/it]
# Songs Collected: 73484
# Year: 1972
# 100%|██████████| 26/26 [00:07<00:00,  3.29it/s]
#  33%|███▎      | 23/70 [02:41<05:57,  7.60s/it]
# Songs Collected: 83465
# Year: 1973
# 100%|██████████| 26/26 [00:07<00:00,  3.53it/s]
#  34%|███▍      | 24/70 [02:49<05:49,  7.60s/it]
# Songs Collected: 94225
# Year: 1974
# 100%|██████████| 26/26 [00:06<00:00,  3.85it/s]
#  36%|███▌      | 25/70 [02:56<05:33,  7.42s/it]
# Songs Collected: 105812
# Year: 1975
# 100%|██████████| 26/26 [00:06<00:00,  3.73it/s]
#  37%|███▋      | 26/70 [03:03<05:23,  7.36s/it]
# Songs Collected: 118173
# Year: 1976
# 100%|██████████| 26/26 [00:06<00:00,  3.77it/s]
#  39%|███▊      | 27/70 [03:10<05:13,  7.29s/it]
# Songs Collected: 131301
# Year: 1977
# 100%|██████████| 26/26 [00:07<00:00,  3.60it/s]
#  40%|████      | 28/70 [03:18<05:08,  7.34s/it]
# Songs Collected: 145267
# Year: 1978
# 100%|██████████| 26/26 [00:07<00:00,  3.62it/s]
#  41%|████▏     | 29/70 [03:25<05:01,  7.36s/it]
# Songs Collected: 160098
# Year: 1979
# 100%|██████████| 26/26 [00:06<00:00,  3.77it/s]
#  43%|████▎     | 30/70 [03:32<04:51,  7.29s/it]
# Songs Collected: 175950
# Year: 1980
# 100%|██████████| 26/26 [00:07<00:00,  3.67it/s]
#  44%|████▍     | 31/70 [03:40<04:44,  7.30s/it]
# Songs Collected: 192919
# Year: 1981
# 100%|██████████| 26/26 [00:06<00:00,  3.83it/s]
#  46%|████▌     | 32/70 [03:47<04:34,  7.22s/it]
# Songs Collected: 210911
# Year: 1982
# 100%|██████████| 26/26 [00:07<00:00,  3.58it/s]
#  47%|████▋     | 33/70 [03:54<04:30,  7.30s/it]
# Songs Collected: 229970
# Year: 1983
# 100%|██████████| 26/26 [00:07<00:00,  3.60it/s]
#  49%|████▊     | 34/70 [04:02<04:24,  7.35s/it]
# Songs Collected: 250119
# Year: 1984
# 100%|██████████| 26/26 [00:06<00:00,  3.72it/s]
#  50%|█████     | 35/70 [04:09<04:15,  7.31s/it]
# Songs Collected: 271373
# Year: 1985
# 100%|██████████| 26/26 [00:07<00:00,  3.52it/s]
#  51%|█████▏    | 36/70 [04:16<04:12,  7.41s/it]
# Songs Collected: 293761
# Year: 1986
# 100%|██████████| 26/26 [00:07<00:00,  3.71it/s]
#  53%|█████▎    | 37/70 [04:24<04:02,  7.36s/it]
# Songs Collected: 317255
# Year: 1987
# 100%|██████████| 26/26 [00:07<00:00,  3.45it/s]
#  54%|█████▍    | 38/70 [04:31<03:59,  7.48s/it]
# Songs Collected: 341879
# Year: 1988
# 100%|██████████| 26/26 [00:06<00:00,  3.75it/s]
#  56%|█████▌    | 39/70 [04:39<03:48,  7.38s/it]
# Songs Collected: 367657
# Year: 1989
# 100%|██████████| 141/141 [00:40<00:00,  3.45it/s]
#  57%|█████▋    | 40/70 [05:20<08:44, 17.50s/it]
# Songs Collected: 394737
# Year: 1990
# 100%|██████████| 141/141 [00:41<00:00,  3.43it/s]
#  59%|█████▊    | 41/70 [06:01<11:55, 24.66s/it]
# Songs Collected: 423071
# Year: 1991
# 100%|██████████| 141/141 [00:41<00:00,  3.41it/s]
#  60%|██████    | 42/70 [06:43<13:53, 29.76s/it]
# Songs Collected: 452638
# Year: 1992
# 100%|██████████| 141/141 [00:43<00:00,  3.23it/s]
#  61%|██████▏   | 43/70 [07:27<15:17, 33.99s/it]
# Songs Collected: 483516
# Year: 1993
# 100%|██████████| 141/141 [00:42<00:00,  3.36it/s]
#  63%|██████▎   | 44/70 [08:09<15:48, 36.48s/it]
# Songs Collected: 515833
# Year: 1994
# 100%|██████████| 141/141 [00:41<00:00,  3.39it/s]
#  64%|██████▍   | 45/70 [08:51<15:52, 38.10s/it]
# Songs Collected: 549618
# Year: 1995
# 100%|██████████| 141/141 [00:41<00:00,  3.37it/s]
#  66%|██████▌   | 46/70 [09:33<15:43, 39.30s/it]
# Songs Collected: 584899
# Year: 1996
# 100%|██████████| 141/141 [00:40<00:00,  3.45it/s]
#  67%|██████▋   | 47/70 [10:14<15:16, 39.86s/it]
# Songs Collected: 621778
# Year: 1997
# 100%|██████████| 141/141 [00:41<00:00,  3.44it/s]
#  69%|██████▊   | 48/70 [10:55<14:46, 40.28s/it]
# Songs Collected: 660191
# Year: 1998
# 100%|██████████| 141/141 [00:41<00:00,  3.43it/s]
#  70%|███████   | 49/70 [11:37<14:12, 40.61s/it]
# Songs Collected: 700102
# Year: 1999
# 100%|██████████| 141/141 [00:41<00:00,  3.38it/s]
#  71%|███████▏  | 50/70 [12:19<13:40, 41.05s/it]
# Songs Collected: 741613
# Year: 2000
# 100%|██████████| 141/141 [00:41<00:00,  3.37it/s]
#  73%|███████▎  | 51/70 [13:01<13:05, 41.36s/it]
# Songs Collected: 784719
# Year: 2001
# 100%|██████████| 141/141 [00:42<00:00,  3.36it/s]
#  74%|███████▍  | 52/70 [13:43<12:29, 41.64s/it]
# Songs Collected: 829479
# Year: 2002
# 100%|██████████| 141/141 [00:41<00:00,  3.41it/s]
#  76%|███████▌  | 53/70 [14:25<11:47, 41.62s/it]
# Songs Collected: 875805
# Year: 2003
# 100%|██████████| 141/141 [00:55<00:00,  2.56it/s]
#  77%|███████▋  | 54/70 [15:20<12:11, 45.73s/it]
# Songs Collected: 923976
# Year: 2004
# 100%|██████████| 141/141 [00:49<00:00,  2.84it/s]
#  79%|███████▊  | 55/70 [16:10<11:46, 47.11s/it]
# Songs Collected: 974314
# Year: 2005
# 100%|██████████| 141/141 [00:41<00:00,  3.39it/s]
#  80%|████████  | 56/70 [16:52<10:37, 45.54s/it]
# Songs Collected: 1026906
# Year: 2006
# 100%|██████████| 141/141 [00:42<00:00,  3.30it/s]
#  81%|████████▏ | 57/70 [17:36<09:43, 44.89s/it]
# Songs Collected: 1081812
# Year: 2007
# 100%|██████████| 141/141 [00:47<00:00,  2.99it/s]
#  83%|████████▎ | 58/70 [18:23<09:08, 45.68s/it]
# Songs Collected: 1139368
# Year: 2008
# 100%|██████████| 141/141 [01:01<00:00,  2.28it/s]
#  84%|████████▍ | 59/70 [19:26<09:17, 50.73s/it]
# Songs Collected: 1199532
# Year: 2009
# 100%|██████████| 141/141 [00:45<00:00,  3.07it/s]
#  86%|████████▌ | 60/70 [20:12<08:13, 49.36s/it]
# Songs Collected: 1262501
# Year: 2010
# 100%|██████████| 141/141 [00:48<00:00,  2.89it/s]
#  87%|████████▋ | 61/70 [21:01<07:23, 49.24s/it]
# Songs Collected: 1328226
# Year: 2011
# 100%|██████████| 141/141 [00:47<00:00,  2.95it/s]
#  89%|████████▊ | 62/70 [21:49<06:30, 48.87s/it]
# Songs Collected: 1396347
# Year: 2012
# 100%|██████████| 141/141 [00:43<00:00,  3.22it/s]
#  90%|█████████ | 63/70 [22:33<05:32, 47.43s/it]
# Songs Collected: 1466936
# Year: 2013
# 100%|██████████| 141/141 [00:43<00:00,  3.21it/s]
#  91%|█████████▏| 64/70 [23:17<04:38, 46.44s/it]
# Songs Collected: 1540146
# Year: 2014
# 100%|██████████| 141/141 [00:43<00:00,  3.27it/s]
#  93%|█████████▎| 65/70 [24:00<03:47, 45.53s/it]
# Songs Collected: 1615809
# Year: 2015
# 100%|██████████| 141/141 [00:44<00:00,  3.19it/s]
#  94%|█████████▍| 66/70 [24:45<03:00, 45.20s/it]
# Songs Collected: 1694368
# Year: 2016
# 100%|██████████| 141/141 [00:51<00:00,  2.76it/s]
#  96%|█████████▌| 67/70 [25:36<02:21, 47.03s/it]
# Songs Collected: 1775812
# Year: 2017
# 100%|██████████| 141/141 [00:45<00:00,  3.10it/s]
#  97%|█████████▋| 68/70 [26:22<01:33, 46.66s/it]
# Songs Collected: 1860754
# Year: 2018
# 100%|██████████| 141/141 [00:47<00:00,  2.99it/s]
#  99%|█████████▊| 69/70 [27:09<00:46, 46.91s/it]
# Songs Collected: 1948506
# Year: 2019
# 100%|██████████| 141/141 [00:53<00:00,  2.61it/s]
# 100%|██████████| 70/70 [28:04<00:00, 24.06s/it]
# Songs Collected: 2038724
# [('Accidents Will Happen (Bing Crosby song)',
#   'https://en.wikipedia.org/wiki/Accidents_Will_Happen_(Bing_Crosby_song)',
#   '1950'),
#  ("Adelaide's Lament",
#   'https://en.wikipedia.org/wiki/Adelaide%27s_Lament',
#   '1950'),
#  ('Adoro a mi tierra',
#   'https://en.wikipedia.org/wiki/Adoro_a_mi_tierra',
#   '1950'),
#  ('(Ah, the Apple Trees) When the World Was Young',
#   'https://en.wikipedia.org/wiki/(Ah,_the_Apple_Trees)_When_the_World_Was_Young',
#   '1950'),
#  ('All My Love (Patti Page song)',
#   'https://en.wikipedia.org/wiki/All_My_Love_(Patti_Page_song)',
#   '1950'),
#  ('American Beauty Rose (song)',
#   'https://en.wikipedia.org/wiki/American_Beauty_Rose_(song)',
#   '1950'),
#  ('Anema e core (song)',
#   'https://en.wikipedia.org/wiki/Anema_e_core_(song)',
#   '1950'),
#  ('Anytime, Any Place, Anywhere',
#   'https://en.wikipedia.org/wiki/Anytime,_Any_Place,_Anywhere',
#   '1950'),
#  ("Auf Wiederseh'n, Sweetheart",
#   'https://en.wikipedia.org/wiki/Auf_Wiederseh%27n,_Sweetheart',
#   '1950'),
#  ('Baby, Baby, Baby (Teresa Brewer song)',
#   'https://en.wikipedia.org/wiki/Baby,_Baby,_Baby_(Teresa_Brewer_song)',
#   '1950'),
#  ('Bad, Bad Whiskey',
#   'https://en.wikipedia.org/wiki/Bad,_Bad_Whiskey',
#   '1950'),
#  ("Baião Ca-Room' Pa Pa",
#   'https://en.wikipedia.org/wiki/Bai%C3%A3o_Ca-Room%27_Pa_Pa',
#   '1950'),
#  ('Be My Love', 'https://en.wikipedia.org/wiki/Be_My_Love', '1950'),
#  ('The Best Thing for You (Would Be Me)',
#   'https://en.wikipedia.org/wiki/The_Best_Thing_for_You_(Would_Be_Me)',
#   '1950'),
#  ('Beyond the Sunset (song)',
#   'https://en.wikipedia.org/wiki/Beyond_the_Sunset_(song)',
#   '1950'),
#  ('Big Blue Diamonds',
#   'https://en.wikipedia.org/wiki/Big_Blue_Diamonds',
#   '1950'),
#  ('Birmingham Bounce',
#   'https://en.wikipedia.org/wiki/Birmingham_Bounce',
#   '1950'),
#  ('The Blacksmith Blues',
#   'https://en.wikipedia.org/wiki/The_Blacksmith_Blues',
#   '1950'),
#  ('Blåveispiken', 'https://en.wikipedia.org/wiki/Bl%C3%A5veispiken', '1950'),
#  ('Bloodshot Eyes (song)',
#   'https://en.wikipedia.org/wiki/Bloodshot_Eyes_(song)',
#   '1950'),
#  ('Bloomdido', 'https://en.wikipedia.org/wiki/Bloomdido', '1950'),
#  ('Blue Light Boogie (song)',
#   'https://en.wikipedia.org/wiki/Blue_Light_Boogie_(song)',
#   '1950'),
#  ('Blue Shadows', 'https://en.wikipedia.org/wiki/Blue_Shadows', '1950'),
#  ('Blue Velvet (song)',
#   'https://en.wikipedia.org/wiki/Blue_Velvet_(song)',
#   '1950'),
#  ("Bonaparte's Retreat (Pee Wee King song)",
#   'https://en.wikipedia.org/wiki/Bonaparte%27s_Retreat_(Pee_Wee_King_song)',
#   '1950'),
#  ('Broken Down Merry-Go-Round',
#   'https://en.wikipedia.org/wiki/Broken_Down_Merry-Go-Round',
#   '1950'),
#  ('Buona Sera', 'https://en.wikipedia.org/wiki/Buona_Sera', '1950'),
#  ('A Bushel and a Peck',
#   'https://en.wikipedia.org/wiki/A_Bushel_and_a_Peck',
#   '1950'),
#  ('Can Anyone Explain? (No! No! No!)',
#   'https://en.wikipedia.org/wiki/Can_Anyone_Explain%3F_(No!_No!_No!)',
#   '1950'),
#  ('Chattanoogie Shoe Shine Boy',
#   'https://en.wikipedia.org/wiki/Chattanoogie_Shoe_Shine_Boy',
#   '1950'),
#  ('Chemirocha', 'https://en.wikipedia.org/wiki/Chemirocha', '1950'),
#  ('Cherry Pink (and Apple Blossom White)',
#   'https://en.wikipedia.org/wiki/Cherry_Pink_(and_Apple_Blossom_White)',
#   '1950'),
#  ('Christmas in Killarney',
#   'https://en.wikipedia.org/wiki/Christmas_in_Killarney',
#   '1950'),
#  ('Cincinnati Dancing Pig',
#   'https://en.wikipedia.org/wiki/Cincinnati_Dancing_Pig',
#   '1950'),
#  ('Conception (song)',
#   'https://en.wikipedia.org/wiki/Conception_(song)',
#   '1950'),
#  ('Count Every Star',
#   'https://en.wikipedia.org/wiki/Count_Every_Star',
#   '1950'),
#  ('The Cry of the Wild Goose',
#   'https://en.wikipedia.org/wiki/The_Cry_of_the_Wild_Goose',
#   '1950'),
#  ("Cuddle Buggin' Baby",
#   'https://en.wikipedia.org/wiki/Cuddle_Buggin%27_Baby',
#   '1950'),
#  ("Cupid's Boogie", 'https://en.wikipedia.org/wiki/Cupid%27s_Boogie', '1950'),
#  ('Deal Me a Hand', 'https://en.wikipedia.org/wiki/Deal_Me_a_Hand', '1950'),
#  ('Dearie', 'https://en.wikipedia.org/wiki/Dearie', '1950'),
#  ('Domino (Louis Ferrari and Don Raye song)',
#   'https://en.wikipedia.org/wiki/Domino_(Louis_Ferrari_and_Don_Raye_song)',
#   '1950'),
#  ('Double Crossing Blues',
#   'https://en.wikipedia.org/wiki/Double_Crossing_Blues',
#   '1950'),
#  ('A Dream Is a Wish Your Heart Makes',
#   'https://en.wikipedia.org/wiki/A_Dream_Is_a_Wish_Your_Heart_Makes',
#   '1950'),
#  ('Echoes (1950 song)',
#   'https://en.wikipedia.org/wiki/Echoes_(1950_song)',
#   '1950'),
#  ('Enclosed One Broken Heart',
#   'https://en.wikipedia.org/wiki/Enclosed_One_Broken_Heart',
#   '1950'),
#  ("(Everybody's Waitin' for) The Man with the Bag",
#   'https://en.wikipedia.org/wiki/(Everybody%27s_Waitin%27_for)_The_Man_with_the_Bag',
#   '1950'),
#  ('Faded Love', 'https://en.wikipedia.org/wiki/Faded_Love', '1950'),
#  ('La flor de la canela',
#   'https://en.wikipedia.org/wiki/La_flor_de_la_canela',
#   '1950'),
#  ('Frosty the Snowman',
#   'https://en.wikipedia.org/wiki/Frosty_the_Snowman',
#   '1950'),
#  ('The Funeral (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/The_Funeral_(Hank_Williams_song)',
#   '1950'),
#  ('Take Me in Your Arms (Eddy Arnold song)',
#   'https://en.wikipedia.org/wiki/Take_Me_in_Your_Arms_(Eddy_Arnold_song)',
#   '1950'),
#  ('Take My Love (Frank Sinatra song)',
#   'https://en.wikipedia.org/wiki/Take_My_Love_(Frank_Sinatra_song)',
#   '1950'),
#  ('Take Possession', 'https://en.wikipedia.org/wiki/Take_Possession', '1950'),
#  ('A Teardrop on a Rose',
#   'https://en.wikipedia.org/wiki/A_Teardrop_on_a_Rose',
#   '1950'),
#  ('Teardrops from My Eyes',
#   'https://en.wikipedia.org/wiki/Teardrops_from_My_Eyes',
#   '1950'),
#  ('Tennessee Border No. 2',
#   'https://en.wikipedia.org/wiki/Tennessee_Border_No._2',
#   '1950'),
#  ("There's No Tomorrow",
#   'https://en.wikipedia.org/wiki/There%27s_No_Tomorrow',
#   '1950'),
#  ("They'll Never Take Her Love from Me",
#   'https://en.wikipedia.org/wiki/They%27ll_Never_Take_Her_Love_from_Me',
#   '1950'),
#  ('The Thing (song)',
#   'https://en.wikipedia.org/wiki/The_Thing_(song)',
#   '1950'),
#  ('Throw Your Love My Way',
#   'https://en.wikipedia.org/wiki/Throw_Your_Love_My_Way',
#   '1950'),
#  ("Why Don't You Love Me (Hank Williams song)",
#   'https://en.wikipedia.org/wiki/Why_Don%27t_You_Love_Me_(Hank_Williams_song)',
#   '1950'),
#  ('Why Should I Cry Over You?',
#   'https://en.wikipedia.org/wiki/Why_Should_I_Cry_Over_You%3F',
#   '1950'),
#  ('Why Should We Try Anymore',
#   'https://en.wikipedia.org/wiki/Why_Should_We_Try_Anymore',
#   '1950'),
#  ('Would I Love You (Love You, Love You)',
#   'https://en.wikipedia.org/wiki/Would_I_Love_You_(Love_You,_Love_You)',
#   '1950'),
#  ('Yipsee-I-O', 'https://en.wikipedia.org/wiki/Yipsee-I-O', '1950'),
#  ("You Don't Have to Be a Baby to Cry",
#   'https://en.wikipedia.org/wiki/You_Don%27t_Have_to_Be_a_Baby_to_Cry',
#   '1950'),
#  ("You're All the World to Me",
#   'https://en.wikipedia.org/wiki/You%27re_All_the_World_to_Me',
#   '1950'),
#  ("You're Just in Love",
#   'https://en.wikipedia.org/wiki/You%27re_Just_in_Love',
#   '1950'),
#  ("You've Still Got a Place in My Heart (song)",
#   'https://en.wikipedia.org/wiki/You%27ve_Still_Got_a_Place_in_My_Heart_(song)',
#   '1950'),
#  ('The Gods Were Angry with Me',
#   'https://en.wikipedia.org/wiki/The_Gods_Were_Angry_with_Me',
#   '1950'),
#  ('The Golden Rocket',
#   'https://en.wikipedia.org/wiki/The_Golden_Rocket',
#   '1950'),
#  ('Hard Luck Blues', 'https://en.wikipedia.org/wiki/Hard_Luck_Blues', '1950'),
#  ('Help Me Understand (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/Help_Me_Understand_(Hank_Williams_song)',
#   '1950'),
#  ('Hillbilly Fever', 'https://en.wikipedia.org/wiki/Hillbilly_Fever', '1950'),
#  ('Hold My Hand (1953 song)',
#   'https://en.wikipedia.org/wiki/Hold_My_Hand_(1953_song)',
#   '1950'),
#  ('Hoop-Dee-Doo', 'https://en.wikipedia.org/wiki/Hoop-Dee-Doo', '1950'),
#  ('Hot Rod Race', 'https://en.wikipedia.org/wiki/Hot_Rod_Race', '1950'),
#  ('How Can You Refuse Him Now',
#   'https://en.wikipedia.org/wiki/How_Can_You_Refuse_Him_Now',
#   '1950'),
#  ("Hymne à l'amour",
#   'https://en.wikipedia.org/wiki/Hymne_%C3%A0_l%27amour',
#   '1950'),
#  ('I Almost Lost My Mind',
#   'https://en.wikipedia.org/wiki/I_Almost_Lost_My_Mind',
#   '1950'),
#  ("I Didn't Slip, I Wasn't Pushed, I Fell",
#   'https://en.wikipedia.org/wiki/I_Didn%27t_Slip,_I_Wasn%27t_Pushed,_I_Fell',
#   '1950'),
#  ("I Don't Care if the Sun Don't Shine",
#   'https://en.wikipedia.org/wiki/I_Don%27t_Care_if_the_Sun_Don%27t_Shine',
#   '1950'),
#  ('I Need You So', 'https://en.wikipedia.org/wiki/I_Need_You_So', '1950'),
#  ('I Overlooked an Orchid',
#   'https://en.wikipedia.org/wiki/I_Overlooked_an_Orchid',
#   '1950'),
#  ('I Taut I Taw a Puddy-Tat',
#   'https://en.wikipedia.org/wiki/I_Taut_I_Taw_a_Puddy-Tat',
#   '1950'),
#  ("I'll Never Be Free",
#   'https://en.wikipedia.org/wiki/I%27ll_Never_Be_Free',
#   '1950'),
#  ("I'll Sail My Ship Alone",
#   'https://en.wikipedia.org/wiki/I%27ll_Sail_My_Ship_Alone',
#   '1950'),
#  ("I'm Moving On (Hank Snow song)",
#   'https://en.wikipedia.org/wiki/I%27m_Moving_On_(Hank_Snow_song)',
#   '1950'),
#  ("I've Never Been in Love Before",
#   'https://en.wikipedia.org/wiki/I%27ve_Never_Been_in_Love_Before',
#   '1950'),
#  ("If I Knew You Were Comin' I'd've Baked a Cake",
#   'https://en.wikipedia.org/wiki/If_I_Knew_You_Were_Comin%27_I%27d%27ve_Baked_a_Cake',
#   '1950'),
#  ('If I Were a Bell',
#   'https://en.wikipedia.org/wiki/If_I_Were_a_Bell',
#   '1950'),
#  ("If You've Got the Money I've Got the Time",
#   'https://en.wikipedia.org/wiki/If_You%27ve_Got_the_Money_I%27ve_Got_the_Time',
#   '1950'),
#  ("It's a Lovely Day Today",
#   'https://en.wikipedia.org/wiki/It%27s_a_Lovely_Day_Today',
#   '1950'),
#  ('Jesus Gave Me Water',
#   'https://en.wikipedia.org/wiki/Jesus_Gave_Me_Water',
#   '1950'),
#  ('Kinderhymne', 'https://en.wikipedia.org/wiki/Kinderhymne', '1950'),
#  ('Kisses Sweeter than Wine',
#   'https://en.wikipedia.org/wiki/Kisses_Sweeter_than_Wine',
#   '1950'),
#  ('Last Night I Had the Strangest Dream',
#   'https://en.wikipedia.org/wiki/Last_Night_I_Had_the_Strangest_Dream',
#   '1950'),
#  ("Let's Go to Church (Next Sunday Morning)",
#   'https://en.wikipedia.org/wiki/Let%27s_Go_to_Church_(Next_Sunday_Morning)',
#   '1950'),
#  ('Letters Have No Arms',
#   'https://en.wikipedia.org/wiki/Letters_Have_No_Arms',
#   '1950'),
#  ('Lilac Wine', 'https://en.wikipedia.org/wiki/Lilac_Wine', '1950'),
#  ('Little Angel with the Dirty Face',
#   'https://en.wikipedia.org/wiki/Little_Angel_with_the_Dirty_Face',
#   '1950'),
#  ('Lonesome Traveller',
#   'https://en.wikipedia.org/wiki/Lonesome_Traveller',
#   '1950'),
#  ('Long Gone Lonesome Blues',
#   'https://en.wikipedia.org/wiki/Long_Gone_Lonesome_Blues',
#   '1950'),
#  ('Lovebug Itch', 'https://en.wikipedia.org/wiki/Lovebug_Itch', '1950'),
#  ('May the Good Lord Bless and Keep You',
#   'https://en.wikipedia.org/wiki/May_the_Good_Lord_Bless_and_Keep_You',
#   '1950'),
#  ('Mr. Touchdown, U.S.A.',
#   'https://en.wikipedia.org/wiki/Mr._Touchdown,_U.S.A.',
#   '1950'),
#  ("Mistrustin' Blues",
#   'https://en.wikipedia.org/wiki/Mistrustin%27_Blues',
#   '1950'),
#  ("Moanin' the Blues",
#   'https://en.wikipedia.org/wiki/Moanin%27_the_Blues',
#   '1950'),
#  ('Mona Lisa (Nat King Cole song)',
#   'https://en.wikipedia.org/wiki/Mona_Lisa_(Nat_King_Cole_song)',
#   '1950'),
#  ('My Baby Left Me', 'https://en.wikipedia.org/wiki/My_Baby_Left_Me', '1950'),
#  ('My Heart Cries for You',
#   'https://en.wikipedia.org/wiki/My_Heart_Cries_for_You',
#   '1950'),
#  ('My Son Calls Another Man Daddy',
#   'https://en.wikipedia.org/wiki/My_Son_Calls_Another_Man_Daddy',
#   '1950'),
#  ('National anthem of Mongolia',
#   'https://en.wikipedia.org/wiki/National_anthem_of_Mongolia',
#   '1950'),
#  ('No Other Love (1950 song)',
#   'https://en.wikipedia.org/wiki/No_Other_Love_(1950_song)',
#   '1950'),
#  ('No, No, Joe', 'https://en.wikipedia.org/wiki/No,_No,_Joe', '1950'),
#  ("Nobody's Lonesome for Me",
#   'https://en.wikipedia.org/wiki/Nobody%27s_Lonesome_for_Me',
#   '1950'),
#  ("One Monkey Don't Stop No Show (song)",
#   'https://en.wikipedia.org/wiki/One_Monkey_Don%27t_Stop_No_Show_(song)',
#   '1950'),
#  ('Òran na Cloiche',
#   'https://en.wikipedia.org/wiki/%C3%92ran_na_Cloiche',
#   '1950'),
#  ('Orange Colored Sky',
#   'https://en.wikipedia.org/wiki/Orange_Colored_Sky',
#   '1950'),
#  ('Patricia (1950 song)',
#   'https://en.wikipedia.org/wiki/Patricia_(1950_song)',
#   '1950'),
#  ('Peachtree Street (song)',
#   'https://en.wikipedia.org/wiki/Peachtree_Street_(song)',
#   '1950'),
#  ('Pink Champagne (Joe Liggins song)',
#   'https://en.wikipedia.org/wiki/Pink_Champagne_(Joe_Liggins_song)',
#   '1950'),
#  ('Please Send Me Someone to Love',
#   'https://en.wikipedia.org/wiki/Please_Send_Me_Someone_to_Love',
#   '1950'),
#  ('Quicksilver (song)',
#   'https://en.wikipedia.org/wiki/Quicksilver_(song)',
#   '1950'),
#  ("(Remember Me) I'm the One Who Loves You",
#   'https://en.wikipedia.org/wiki/(Remember_Me)_I%27m_the_One_Who_Loves_You',
#   '1950'),
#  ("Rollin' Stone (Muddy Waters song)",
#   'https://en.wikipedia.org/wiki/Rollin%27_Stone_(Muddy_Waters_song)',
#   '1950'),
#  ('The Roving Kind (song)',
#   'https://en.wikipedia.org/wiki/The_Roving_Kind_(song)',
#   '1950'),
#  ("Sam's Song (song)",
#   'https://en.wikipedia.org/wiki/Sam%27s_Song_(song)',
#   '1950'),
#  ('Shifting Whispering Sands',
#   'https://en.wikipedia.org/wiki/Shifting_Whispering_Sands',
#   '1950'),
#  ('The Shotgun Boogie',
#   'https://en.wikipedia.org/wiki/The_Shotgun_Boogie',
#   '1950'),
#  ('Silver Bells', 'https://en.wikipedia.org/wiki/Silver_Bells', '1950'),
#  ('Simply a Waltz', 'https://en.wikipedia.org/wiki/Simply_a_Waltz', '1950'),
#  ('Sing, Sweet Nightingale',
#   'https://en.wikipedia.org/wiki/Sing,_Sweet_Nightingale',
#   '1950'),
#  ("Sit Down, You're Rockin' the Boat",
#   'https://en.wikipedia.org/wiki/Sit_Down,_You%27re_Rockin%27_the_Boat',
#   '1950'),
#  ('Accidents Will Happen (Bing Crosby song)',
#   'https://en.wikipedia.org/wiki/Accidents_Will_Happen_(Bing_Crosby_song)',
#   '1950'),
#  ("Adelaide's Lament",
#   'https://en.wikipedia.org/wiki/Adelaide%27s_Lament',
#   '1950'),
#  ('Adoro a mi tierra',
#   'https://en.wikipedia.org/wiki/Adoro_a_mi_tierra',
#   '1950'),
#  ('(Ah, the Apple Trees) When the World Was Young',
#   'https://en.wikipedia.org/wiki/(Ah,_the_Apple_Trees)_When_the_World_Was_Young',
#   '1950'),
#  ('All My Love (Patti Page song)',
#   'https://en.wikipedia.org/wiki/All_My_Love_(Patti_Page_song)',
#   '1950'),
#  ('American Beauty Rose (song)',
#   'https://en.wikipedia.org/wiki/American_Beauty_Rose_(song)',
#   '1950'),
#  ('Anema e core (song)',
#   'https://en.wikipedia.org/wiki/Anema_e_core_(song)',
#   '1950'),
#  ('Anytime, Any Place, Anywhere',
#   'https://en.wikipedia.org/wiki/Anytime,_Any_Place,_Anywhere',
#   '1950'),
#  ("Auf Wiederseh'n, Sweetheart",
#   'https://en.wikipedia.org/wiki/Auf_Wiederseh%27n,_Sweetheart',
#   '1950'),
#  ('Baby, Baby, Baby (Teresa Brewer song)',
#   'https://en.wikipedia.org/wiki/Baby,_Baby,_Baby_(Teresa_Brewer_song)',
#   '1950'),
#  ('Bad, Bad Whiskey',
#   'https://en.wikipedia.org/wiki/Bad,_Bad_Whiskey',
#   '1950'),
#  ("Baião Ca-Room' Pa Pa",
#   'https://en.wikipedia.org/wiki/Bai%C3%A3o_Ca-Room%27_Pa_Pa',
#   '1950'),
#  ('Be My Love', 'https://en.wikipedia.org/wiki/Be_My_Love', '1950'),
#  ('The Best Thing for You (Would Be Me)',
#   'https://en.wikipedia.org/wiki/The_Best_Thing_for_You_(Would_Be_Me)',
#   '1950'),
#  ('Beyond the Sunset (song)',
#   'https://en.wikipedia.org/wiki/Beyond_the_Sunset_(song)',
#   '1950'),
#  ('Big Blue Diamonds',
#   'https://en.wikipedia.org/wiki/Big_Blue_Diamonds',
#   '1950'),
#  ('Birmingham Bounce',
#   'https://en.wikipedia.org/wiki/Birmingham_Bounce',
#   '1950'),
#  ('The Blacksmith Blues',
#   'https://en.wikipedia.org/wiki/The_Blacksmith_Blues',
#   '1950'),
#  ('Blåveispiken', 'https://en.wikipedia.org/wiki/Bl%C3%A5veispiken', '1950'),
#  ('Bloodshot Eyes (song)',
#   'https://en.wikipedia.org/wiki/Bloodshot_Eyes_(song)',
#   '1950'),
#  ('Bloomdido', 'https://en.wikipedia.org/wiki/Bloomdido', '1950'),
#  ('Blue Light Boogie (song)',
#   'https://en.wikipedia.org/wiki/Blue_Light_Boogie_(song)',
#   '1950'),
#  ('Blue Shadows', 'https://en.wikipedia.org/wiki/Blue_Shadows', '1950'),
#  ('Blue Velvet (song)',
#   'https://en.wikipedia.org/wiki/Blue_Velvet_(song)',
#   '1950'),
#  ("Bonaparte's Retreat (Pee Wee King song)",
#   'https://en.wikipedia.org/wiki/Bonaparte%27s_Retreat_(Pee_Wee_King_song)',
#   '1950'),
#  ('Broken Down Merry-Go-Round',
#   'https://en.wikipedia.org/wiki/Broken_Down_Merry-Go-Round',
#   '1950'),
#  ('Buona Sera', 'https://en.wikipedia.org/wiki/Buona_Sera', '1950'),
#  ('A Bushel and a Peck',
#   'https://en.wikipedia.org/wiki/A_Bushel_and_a_Peck',
#   '1950'),
#  ('Can Anyone Explain? (No! No! No!)',
#   'https://en.wikipedia.org/wiki/Can_Anyone_Explain%3F_(No!_No!_No!)',
#   '1950'),
#  ('Chattanoogie Shoe Shine Boy',
#   'https://en.wikipedia.org/wiki/Chattanoogie_Shoe_Shine_Boy',
#   '1950'),
#  ('Chemirocha', 'https://en.wikipedia.org/wiki/Chemirocha', '1950'),
#  ('Cherry Pink (and Apple Blossom White)',
#   'https://en.wikipedia.org/wiki/Cherry_Pink_(and_Apple_Blossom_White)',
#   '1950'),
#  ('Christmas in Killarney',
#   'https://en.wikipedia.org/wiki/Christmas_in_Killarney',
#   '1950'),
#  ('Cincinnati Dancing Pig',
#   'https://en.wikipedia.org/wiki/Cincinnati_Dancing_Pig',
#   '1950'),
#  ('Conception (song)',
#   'https://en.wikipedia.org/wiki/Conception_(song)',
#   '1950'),
#  ('Count Every Star',
#   'https://en.wikipedia.org/wiki/Count_Every_Star',
#   '1950'),
#  ('The Cry of the Wild Goose',
#   'https://en.wikipedia.org/wiki/The_Cry_of_the_Wild_Goose',
#   '1950'),
#  ("Cuddle Buggin' Baby",
#   'https://en.wikipedia.org/wiki/Cuddle_Buggin%27_Baby',
#   '1950'),
#  ("Cupid's Boogie", 'https://en.wikipedia.org/wiki/Cupid%27s_Boogie', '1950'),
#  ('Deal Me a Hand', 'https://en.wikipedia.org/wiki/Deal_Me_a_Hand', '1950'),
#  ('Dearie', 'https://en.wikipedia.org/wiki/Dearie', '1950'),
#  ('Domino (Louis Ferrari and Don Raye song)',
#   'https://en.wikipedia.org/wiki/Domino_(Louis_Ferrari_and_Don_Raye_song)',
#   '1950'),
#  ('Double Crossing Blues',
#   'https://en.wikipedia.org/wiki/Double_Crossing_Blues',
#   '1950'),
#  ('A Dream Is a Wish Your Heart Makes',
#   'https://en.wikipedia.org/wiki/A_Dream_Is_a_Wish_Your_Heart_Makes',
#   '1950'),
#  ('Echoes (1950 song)',
#   'https://en.wikipedia.org/wiki/Echoes_(1950_song)',
#   '1950'),
#  ('Enclosed One Broken Heart',
#   'https://en.wikipedia.org/wiki/Enclosed_One_Broken_Heart',
#   '1950'),
#  ("(Everybody's Waitin' for) The Man with the Bag",
#   'https://en.wikipedia.org/wiki/(Everybody%27s_Waitin%27_for)_The_Man_with_the_Bag',
#   '1950'),
#  ('Faded Love', 'https://en.wikipedia.org/wiki/Faded_Love', '1950'),
#  ('La flor de la canela',
#   'https://en.wikipedia.org/wiki/La_flor_de_la_canela',
#   '1950'),
#  ('Frosty the Snowman',
#   'https://en.wikipedia.org/wiki/Frosty_the_Snowman',
#   '1950'),
#  ('The Funeral (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/The_Funeral_(Hank_Williams_song)',
#   '1950'),
#  ('Take Me in Your Arms (Eddy Arnold song)',
#   'https://en.wikipedia.org/wiki/Take_Me_in_Your_Arms_(Eddy_Arnold_song)',
#   '1950'),
#  ('Take My Love (Frank Sinatra song)',
#   'https://en.wikipedia.org/wiki/Take_My_Love_(Frank_Sinatra_song)',
#   '1950'),
#  ('Take Possession', 'https://en.wikipedia.org/wiki/Take_Possession', '1950'),
#  ('A Teardrop on a Rose',
#   'https://en.wikipedia.org/wiki/A_Teardrop_on_a_Rose',
#   '1950'),
#  ('Teardrops from My Eyes',
#   'https://en.wikipedia.org/wiki/Teardrops_from_My_Eyes',
#   '1950'),
#  ('Tennessee Border No. 2',
#   'https://en.wikipedia.org/wiki/Tennessee_Border_No._2',
#   '1950'),
#  ("There's No Tomorrow",
#   'https://en.wikipedia.org/wiki/There%27s_No_Tomorrow',
#   '1950'),
#  ("They'll Never Take Her Love from Me",
#   'https://en.wikipedia.org/wiki/They%27ll_Never_Take_Her_Love_from_Me',
#   '1950'),
#  ('The Thing (song)',
#   'https://en.wikipedia.org/wiki/The_Thing_(song)',
#   '1950'),
#  ('Throw Your Love My Way',
#   'https://en.wikipedia.org/wiki/Throw_Your_Love_My_Way',
#   '1950'),
#  ("Why Don't You Love Me (Hank Williams song)",
#   'https://en.wikipedia.org/wiki/Why_Don%27t_You_Love_Me_(Hank_Williams_song)',
#   '1950'),
#  ('Why Should I Cry Over You?',
#   'https://en.wikipedia.org/wiki/Why_Should_I_Cry_Over_You%3F',
#   '1950'),
#  ('Why Should We Try Anymore',
#   'https://en.wikipedia.org/wiki/Why_Should_We_Try_Anymore',
#   '1950'),
#  ('Would I Love You (Love You, Love You)',
#   'https://en.wikipedia.org/wiki/Would_I_Love_You_(Love_You,_Love_You)',
#   '1950'),
#  ('Yipsee-I-O', 'https://en.wikipedia.org/wiki/Yipsee-I-O', '1950'),
#  ("You Don't Have to Be a Baby to Cry",
#   'https://en.wikipedia.org/wiki/You_Don%27t_Have_to_Be_a_Baby_to_Cry',
#   '1950'),
#  ("You're All the World to Me",
#   'https://en.wikipedia.org/wiki/You%27re_All_the_World_to_Me',
#   '1950'),
#  ("You're Just in Love",
#   'https://en.wikipedia.org/wiki/You%27re_Just_in_Love',
#   '1950'),
#  ("You've Still Got a Place in My Heart (song)",
#   'https://en.wikipedia.org/wiki/You%27ve_Still_Got_a_Place_in_My_Heart_(song)',
#   '1950'),
#  ('The Gods Were Angry with Me',
#   'https://en.wikipedia.org/wiki/The_Gods_Were_Angry_with_Me',
#   '1950'),
#  ('The Golden Rocket',
#   'https://en.wikipedia.org/wiki/The_Golden_Rocket',
#   '1950'),
#  ('Hard Luck Blues', 'https://en.wikipedia.org/wiki/Hard_Luck_Blues', '1950'),
#  ('Help Me Understand (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/Help_Me_Understand_(Hank_Williams_song)',
#   '1950'),
#  ('Hillbilly Fever', 'https://en.wikipedia.org/wiki/Hillbilly_Fever', '1950'),
#  ('Hold My Hand (1953 song)',
#   'https://en.wikipedia.org/wiki/Hold_My_Hand_(1953_song)',
#   '1950'),
#  ('Hoop-Dee-Doo', 'https://en.wikipedia.org/wiki/Hoop-Dee-Doo', '1950'),
#  ('Hot Rod Race', 'https://en.wikipedia.org/wiki/Hot_Rod_Race', '1950'),
#  ('How Can You Refuse Him Now',
#   'https://en.wikipedia.org/wiki/How_Can_You_Refuse_Him_Now',
#   '1950'),
#  ("Hymne à l'amour",
#   'https://en.wikipedia.org/wiki/Hymne_%C3%A0_l%27amour',
#   '1950'),
#  ('I Almost Lost My Mind',
#   'https://en.wikipedia.org/wiki/I_Almost_Lost_My_Mind',
#   '1950'),
#  ("I Didn't Slip, I Wasn't Pushed, I Fell",
#   'https://en.wikipedia.org/wiki/I_Didn%27t_Slip,_I_Wasn%27t_Pushed,_I_Fell',
#   '1950'),
#  ("I Don't Care if the Sun Don't Shine",
#   'https://en.wikipedia.org/wiki/I_Don%27t_Care_if_the_Sun_Don%27t_Shine',
#   '1950'),
#  ('I Need You So', 'https://en.wikipedia.org/wiki/I_Need_You_So', '1950'),
#  ('I Overlooked an Orchid',
#   'https://en.wikipedia.org/wiki/I_Overlooked_an_Orchid',
#   '1950'),
#  ('I Taut I Taw a Puddy-Tat',
#   'https://en.wikipedia.org/wiki/I_Taut_I_Taw_a_Puddy-Tat',
#   '1950'),
#  ("I'll Never Be Free",
#   'https://en.wikipedia.org/wiki/I%27ll_Never_Be_Free',
#   '1950'),
#  ("I'll Sail My Ship Alone",
#   'https://en.wikipedia.org/wiki/I%27ll_Sail_My_Ship_Alone',
#   '1950'),
#  ("I'm Moving On (Hank Snow song)",
#   'https://en.wikipedia.org/wiki/I%27m_Moving_On_(Hank_Snow_song)',
#   '1950'),
#  ("I've Never Been in Love Before",
#   'https://en.wikipedia.org/wiki/I%27ve_Never_Been_in_Love_Before',
#   '1950'),
#  ("If I Knew You Were Comin' I'd've Baked a Cake",
#   'https://en.wikipedia.org/wiki/If_I_Knew_You_Were_Comin%27_I%27d%27ve_Baked_a_Cake',
#   '1950'),
#  ('If I Were a Bell',
#   'https://en.wikipedia.org/wiki/If_I_Were_a_Bell',
#   '1950'),
#  ("If You've Got the Money I've Got the Time",
#   'https://en.wikipedia.org/wiki/If_You%27ve_Got_the_Money_I%27ve_Got_the_Time',
#   '1950'),
#  ("It's a Lovely Day Today",
#   'https://en.wikipedia.org/wiki/It%27s_a_Lovely_Day_Today',
#   '1950'),
#  ('Jesus Gave Me Water',
#   'https://en.wikipedia.org/wiki/Jesus_Gave_Me_Water',
#   '1950'),
#  ('Kinderhymne', 'https://en.wikipedia.org/wiki/Kinderhymne', '1950'),
#  ('Kisses Sweeter than Wine',
#   'https://en.wikipedia.org/wiki/Kisses_Sweeter_than_Wine',
#   '1950'),
#  ('Last Night I Had the Strangest Dream',
#   'https://en.wikipedia.org/wiki/Last_Night_I_Had_the_Strangest_Dream',
#   '1950'),
#  ("Let's Go to Church (Next Sunday Morning)",
#   'https://en.wikipedia.org/wiki/Let%27s_Go_to_Church_(Next_Sunday_Morning)',
#   '1950'),
#  ('Letters Have No Arms',
#   'https://en.wikipedia.org/wiki/Letters_Have_No_Arms',
#   '1950'),
#  ('Lilac Wine', 'https://en.wikipedia.org/wiki/Lilac_Wine', '1950'),
#  ('Little Angel with the Dirty Face',
#   'https://en.wikipedia.org/wiki/Little_Angel_with_the_Dirty_Face',
#   '1950'),
#  ('Lonesome Traveller',
#   'https://en.wikipedia.org/wiki/Lonesome_Traveller',
#   '1950'),
#  ('Long Gone Lonesome Blues',
#   'https://en.wikipedia.org/wiki/Long_Gone_Lonesome_Blues',
#   '1950'),
#  ('Lovebug Itch', 'https://en.wikipedia.org/wiki/Lovebug_Itch', '1950'),
#  ('May the Good Lord Bless and Keep You',
#   'https://en.wikipedia.org/wiki/May_the_Good_Lord_Bless_and_Keep_You',
#   '1950'),
#  ('Mr. Touchdown, U.S.A.',
#   'https://en.wikipedia.org/wiki/Mr._Touchdown,_U.S.A.',
#   '1950'),
#  ("Mistrustin' Blues",
#   'https://en.wikipedia.org/wiki/Mistrustin%27_Blues',
#   '1950'),
#  ("Moanin' the Blues",
#   'https://en.wikipedia.org/wiki/Moanin%27_the_Blues',
#   '1950'),
#  ('Mona Lisa (Nat King Cole song)',
#   'https://en.wikipedia.org/wiki/Mona_Lisa_(Nat_King_Cole_song)',
#   '1950'),
#  ('My Baby Left Me', 'https://en.wikipedia.org/wiki/My_Baby_Left_Me', '1950'),
#  ('My Heart Cries for You',
#   'https://en.wikipedia.org/wiki/My_Heart_Cries_for_You',
#   '1950'),
#  ('My Son Calls Another Man Daddy',
#   'https://en.wikipedia.org/wiki/My_Son_Calls_Another_Man_Daddy',
#   '1950'),
#  ('National anthem of Mongolia',
#   'https://en.wikipedia.org/wiki/National_anthem_of_Mongolia',
#   '1950'),
#  ('No Other Love (1950 song)',
#   'https://en.wikipedia.org/wiki/No_Other_Love_(1950_song)',
#   '1950'),
#  ('No, No, Joe', 'https://en.wikipedia.org/wiki/No,_No,_Joe', '1950'),
#  ("Nobody's Lonesome for Me",
#   'https://en.wikipedia.org/wiki/Nobody%27s_Lonesome_for_Me',
#   '1950'),
#  ("One Monkey Don't Stop No Show (song)",
#   'https://en.wikipedia.org/wiki/One_Monkey_Don%27t_Stop_No_Show_(song)',
#   '1950'),
#  ('Òran na Cloiche',
#   'https://en.wikipedia.org/wiki/%C3%92ran_na_Cloiche',
#   '1950'),
#  ('Orange Colored Sky',
#   'https://en.wikipedia.org/wiki/Orange_Colored_Sky',
#   '1950'),
#  ('Patricia (1950 song)',
#   'https://en.wikipedia.org/wiki/Patricia_(1950_song)',
#   '1950'),
#  ('Peachtree Street (song)',
#   'https://en.wikipedia.org/wiki/Peachtree_Street_(song)',
#   '1950'),
#  ('Pink Champagne (Joe Liggins song)',
#   'https://en.wikipedia.org/wiki/Pink_Champagne_(Joe_Liggins_song)',
#   '1950'),
#  ('Please Send Me Someone to Love',
#   'https://en.wikipedia.org/wiki/Please_Send_Me_Someone_to_Love',
#   '1950'),
#  ('Quicksilver (song)',
#   'https://en.wikipedia.org/wiki/Quicksilver_(song)',
#   '1950'),
#  ("(Remember Me) I'm the One Who Loves You",
#   'https://en.wikipedia.org/wiki/(Remember_Me)_I%27m_the_One_Who_Loves_You',
#   '1950'),
#  ("Rollin' Stone (Muddy Waters song)",
#   'https://en.wikipedia.org/wiki/Rollin%27_Stone_(Muddy_Waters_song)',
#   '1950'),
#  ('The Roving Kind (song)',
#   'https://en.wikipedia.org/wiki/The_Roving_Kind_(song)',
#   '1950'),
#  ("Sam's Song (song)",
#   'https://en.wikipedia.org/wiki/Sam%27s_Song_(song)',
#   '1950'),
#  ('Shifting Whispering Sands',
#   'https://en.wikipedia.org/wiki/Shifting_Whispering_Sands',
#   '1950'),
#  ('The Shotgun Boogie',
#   'https://en.wikipedia.org/wiki/The_Shotgun_Boogie',
#   '1950'),
#  ('Silver Bells', 'https://en.wikipedia.org/wiki/Silver_Bells', '1950'),
#  ('Simply a Waltz', 'https://en.wikipedia.org/wiki/Simply_a_Waltz', '1950'),
#  ('Sing, Sweet Nightingale',
#   'https://en.wikipedia.org/wiki/Sing,_Sweet_Nightingale',
#   '1950'),
#  ("Sit Down, You're Rockin' the Boat",
#   'https://en.wikipedia.org/wiki/Sit_Down,_You%27re_Rockin%27_the_Boat',
#   '1950'),
#  ('Alice in Wonderland (song)',
#   'https://en.wikipedia.org/wiki/Alice_in_Wonderland_(song)',
#   '1951'),
#  ('All in the Golden Afternoon',
#   'https://en.wikipedia.org/wiki/All_in_the_Golden_Afternoon',
#   '1951'),
#  ('All the Love I Ever Had',
#   'https://en.wikipedia.org/wiki/All_the_Love_I_Ever_Had',
#   '1951'),
#  ('Allentown Jail', 'https://en.wikipedia.org/wiki/Allentown_Jail', '1951'),
#  ('Alone and Forsaken',
#   'https://en.wikipedia.org/wiki/Alone_and_Forsaken',
#   '1951'),
#  ('Always Late with Your Kisses',
#   'https://en.wikipedia.org/wiki/Always_Late_with_Your_Kisses',
#   '1951'),
#  ('And So to Sleep Again',
#   'https://en.wikipedia.org/wiki/And_So_to_Sleep_Again',
#   '1951'),
#  ('Anywhere I Wander',
#   'https://en.wikipedia.org/wiki/Anywhere_I_Wander',
#   '1951'),
#  ('As You Are (Dean Martin song)',
#   'https://en.wikipedia.org/wiki/As_You_Are_(Dean_Martin_song)',
#   '1951'),
#  ('Au Privave', 'https://en.wikipedia.org/wiki/Au_Privave', '1951'),
#  ('Awaara Hoon', 'https://en.wikipedia.org/wiki/Awaara_Hoon', '1951'),
#  ("Baby, We're Really in Love",
#   'https://en.wikipedia.org/wiki/Baby,_We%27re_Really_in_Love',
#   '1951'),
#  ('Bayou Pon Pon', 'https://en.wikipedia.org/wiki/Bayou_Pon_Pon', '1951'),
#  ("Be My Life's Companion",
#   'https://en.wikipedia.org/wiki/Be_My_Life%27s_Companion',
#   '1951'),
#  ('Beautiful Brown Eyes',
#   'https://en.wikipedia.org/wiki/Beautiful_Brown_Eyes',
#   '1951'),
#  ('Bermuda (song)', 'https://en.wikipedia.org/wiki/Bermuda_(song)', '1951'),
#  ('Bessie the Heifer',
#   'https://en.wikipedia.org/wiki/Bessie_the_Heifer',
#   '1951'),
#  ("Birks' Works (composition)",
#   'https://en.wikipedia.org/wiki/Birks%27_Works_(composition)',
#   '1951'),
#  ('Black Night (Charles Brown song)',
#   'https://en.wikipedia.org/wiki/Black_Night_(Charles_Brown_song)',
#   '1951'),
#  ('Black Strap Molasses',
#   'https://en.wikipedia.org/wiki/Black_Strap_Molasses',
#   '1951'),
#  ('Blue Tango', 'https://en.wikipedia.org/wiki/Blue_Tango', '1951'),
#  ('Bluebird Island', 'https://en.wikipedia.org/wiki/Bluebird_Island', '1951'),
#  ('Blues for Alice', 'https://en.wikipedia.org/wiki/Blues_for_Alice', '1951'),
#  ('California Zephyr (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/California_Zephyr_(Hank_Williams_song)',
#   '1951'),
#  ('Chains of Love (Ahmet Ertegun song)',
#   'https://en.wikipedia.org/wiki/Chains_of_Love_(Ahmet_Ertegun_song)',
#   '1951'),
#  ("Christmas Time's A-Comin'",
#   'https://en.wikipedia.org/wiki/Christmas_Time%27s_A-Comin%27',
#   '1951'),
#  ('Cold, Cold Heart',
#   'https://en.wikipedia.org/wiki/Cold,_Cold_Heart',
#   '1951'),
#  ('Countryfied (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/Countryfied_(Hank_Williams_song)',
#   '1951'),
#  ('Crazy Heart (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/Crazy_Heart_(Hank_Williams_song)',
#   '1951'),
#  ('Cry (Churchill Kohlman song)',
#   'https://en.wikipedia.org/wiki/Cry_(Churchill_Kohlman_song)',
#   '1951'),
#  ('Dear John (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/Dear_John_(Hank_Williams_song)',
#   '1951'),
#  ("Don't Cry (Édith Piaf song)",
#   'https://en.wikipedia.org/wiki/Don%27t_Cry_(%C3%89dith_Piaf_song)',
#   '1951'),
#  ("Don't You Know I Love You",
#   'https://en.wikipedia.org/wiki/Don%27t_You_Know_I_Love_You',
#   '1951'),
#  ("Down the Trail of Achin' Hearts",
#   'https://en.wikipedia.org/wiki/Down_the_Trail_of_Achin%27_Hearts',
#   '1951'),
#  ('Drown in My Own Tears',
#   'https://en.wikipedia.org/wiki/Drown_in_My_Own_Tears',
#   '1951'),
#  ('Eyesight to the Blind',
#   'https://en.wikipedia.org/wiki/Eyesight_to_the_Blind',
#   '1951'),
#  ('Fool, Fool, Fool',
#   'https://en.wikipedia.org/wiki/Fool,_Fool,_Fool',
#   '1951'),
#  ('Four Walls (Jim Reeves song)',
#   'https://en.wikipedia.org/wiki/Four_Walls_(Jim_Reeves_song)',
#   '1951'),
#  ('From This Moment On (Cole Porter song)',
#   'https://en.wikipedia.org/wiki/From_This_Moment_On_(Cole_Porter_song)',
#   '1951'),
#  ('Getting to Know You (song)',
#   'https://en.wikipedia.org/wiki/Getting_to_Know_You_(song)',
#   '1951'),
#  ('Gomen-nasai (song)',
#   'https://en.wikipedia.org/wiki/Gomen-nasai_(song)',
#   '1951'),
#  ("Gone Fishin' (song)",
#   'https://en.wikipedia.org/wiki/Gone_Fishin%27_(song)',
#   '1951'),
#  ('Gonna Get Along Without Ya Now',
#   'https://en.wikipedia.org/wiki/Gonna_Get_Along_Without_Ya_Now',
#   '1951'),
#  ('Good Morning, Mister Echo',
#   'https://en.wikipedia.org/wiki/Good_Morning,_Mister_Echo',
#   '1951'),
#  ('Got You on My Mind (song)',
#   'https://en.wikipedia.org/wiki/Got_You_on_My_Mind_(song)',
#   '1951'),
#  ('Half as Much', 'https://en.wikipedia.org/wiki/Half_as_Much', '1951'),
#  ('Happy Trails (song)',
#   'https://en.wikipedia.org/wiki/Happy_Trails_(song)',
#   '1951'),
#  ('Heart Strings (Eddy Arnold song)',
#   'https://en.wikipedia.org/wiki/Heart_Strings_(Eddy_Arnold_song)',
#   '1951'),
#  ('Hello, Young Lovers (song)',
#   'https://en.wikipedia.org/wiki/Hello,_Young_Lovers_(song)',
#   '1951'),
#  ('A Home in Heaven',
#   'https://en.wikipedia.org/wiki/A_Home_in_Heaven',
#   '1951'),
#  ('How I Got Over', 'https://en.wikipedia.org/wiki/How_I_Got_Over', '1951'),
#  ('How Many More Years',
#   'https://en.wikipedia.org/wiki/How_Many_More_Years',
#   '1951'),
#  ("Howlin' at the Moon",
#   'https://en.wikipedia.org/wiki/Howlin%27_at_the_Moon',
#   '1951'),
#  ("I Can't Escape from You (Hank Williams song)",
#   'https://en.wikipedia.org/wiki/I_Can%27t_Escape_from_You_(Hank_Williams_song)',
#   '1951'),
#  ("I Can't Help It (If I'm Still in Love with You)",
#   'https://en.wikipedia.org/wiki/I_Can%27t_Help_It_(If_I%27m_Still_in_Love_with_You)',
#   '1951'),
#  ('I Have Dreamed (song)',
#   'https://en.wikipedia.org/wiki/I_Have_Dreamed_(song)',
#   '1951'),
#  ('(I Heard That) Lonesome Whistle',
#   'https://en.wikipedia.org/wiki/(I_Heard_That)_Lonesome_Whistle',
#   '1951'),
#  ('I Love the Way You Say Goodnight',
#   'https://en.wikipedia.org/wiki/I_Love_the_Way_You_Say_Goodnight',
#   '1951'),
#  ('I Want to Be with You Always',
#   'https://en.wikipedia.org/wiki/I_Want_to_Be_with_You_Always',
#   '1951'),
#  ('I Whistle a Happy Tune',
#   'https://en.wikipedia.org/wiki/I_Whistle_a_Happy_Tune',
#   '1951'),
#  ("I'd Still Want You",
#   'https://en.wikipedia.org/wiki/I%27d_Still_Want_You',
#   '1951'),
#  ("I'm a Fool to Want You",
#   'https://en.wikipedia.org/wiki/I%27m_a_Fool_to_Want_You',
#   '1951'),
#  ("(I'm Gonna) Sing, Sing, Sing",
#   'https://en.wikipedia.org/wiki/(I%27m_Gonna)_Sing,_Sing,_Sing',
#   '1951'),
#  ("I'm In A Crowd But Oh So Alone",
#   'https://en.wikipedia.org/wiki/I%27m_In_A_Crowd_But_Oh_So_Alone',
#   '1951'),
#  ("I'm in the Mood (John Lee Hooker song)",
#   'https://en.wikipedia.org/wiki/I%27m_in_the_Mood_(John_Lee_Hooker_song)',
#   '1951'),
#  ("I'm Sorry for You, My Friend",
#   'https://en.wikipedia.org/wiki/I%27m_Sorry_for_You,_My_Friend',
#   '1951'),
#  ("I've Been Down That Road Before",
#   'https://en.wikipedia.org/wiki/I%27ve_Been_Down_That_Road_Before',
#   '1951'),
#  ('In the Cool, Cool, Cool of the Evening',
#   'https://en.wikipedia.org/wiki/In_the_Cool,_Cool,_Cool_of_the_Evening',
#   '1951'),
#  ('Iowa Fight Song', 'https://en.wikipedia.org/wiki/Iowa_Fight_Song', '1951'),
#  ("It Ain't the Meat (It's the Motion)",
#   'https://en.wikipedia.org/wiki/It_Ain%27t_the_Meat_(It%27s_the_Motion)',
#   '1951'),
#  ('It Is No Secret', 'https://en.wikipedia.org/wiki/It_Is_No_Secret', '1951'),
#  ("It's All in the Game (song)",
#   'https://en.wikipedia.org/wiki/It%27s_All_in_the_Game_(song)',
#   '1951'),
#  ("It's Beginning to Look a Lot Like Christmas",
#   'https://en.wikipedia.org/wiki/It%27s_Beginning_to_Look_a_Lot_Like_Christmas',
#   '1951'),
#  ("It's Oh So Quiet",
#   'https://en.wikipedia.org/wiki/It%27s_Oh_So_Quiet',
#   '1951'),
#  ("It's Only Money (1951 song)",
#   'https://en.wikipedia.org/wiki/It%27s_Only_Money_(1951_song)',
#   '1951'),
#  ('Jezebel (Frankie Laine song)',
#   'https://en.wikipedia.org/wiki/Jezebel_(Frankie_Laine_song)',
#   '1951'),
#  ('Josephine (Wayne King song)',
#   'https://en.wikipedia.org/wiki/Josephine_(Wayne_King_song)',
#   '1951'),
#  ('Junco Partner', 'https://en.wikipedia.org/wiki/Junco_Partner', '1951'),
#  ("Keep On Churnin' (Till the Butter Comes)",
#   'https://en.wikipedia.org/wiki/Keep_On_Churnin%27_(Till_the_Butter_Comes)',
#   '1951'),
#  ('Last Train to San Fernando',
#   'https://en.wikipedia.org/wiki/Last_Train_to_San_Fernando',
#   '1951'),
#  ('Let Old Mother Nature Have Her Way',
#   'https://en.wikipedia.org/wiki/Let_Old_Mother_Nature_Have_Her_Way',
#   '1951'),
#  ("Let's Live a Little (song)",
#   'https://en.wikipedia.org/wiki/Let%27s_Live_a_Little_(song)',
#   '1951'),
#  ("Let's Turn Back the Years",
#   'https://en.wikipedia.org/wiki/Let%27s_Turn_Back_the_Years',
#   '1951'),
#  ("The Little House We Built (Just o'er the Hill)",
#   'https://en.wikipedia.org/wiki/The_Little_House_We_Built_(Just_o%27er_the_Hill)',
#   '1951'),
#  ('The Little White Cloud That Cried',
#   'https://en.wikipedia.org/wiki/The_Little_White_Cloud_That_Cried',
#   '1951'),
#  ('Long Distance Call (Muddy Waters song)',
#   'https://en.wikipedia.org/wiki/Long_Distance_Call_(Muddy_Waters_song)',
#   '1951'),
#  ('Longing for You', 'https://en.wikipedia.org/wiki/Longing_for_You', '1951'),
#  ('Look What Thoughts Will Do',
#   'https://en.wikipedia.org/wiki/Look_What_Thoughts_Will_Do',
#   '1951'),
#  ('Malafemmena', 'https://en.wikipedia.org/wiki/Malafemmena', '1951'),
#  ('Me and My Broken Heart (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/Me_and_My_Broken_Heart_(Hank_Williams_song)',
#   '1951'),
#  ('Mister and Mississippi',
#   'https://en.wikipedia.org/wiki/Mister_and_Mississippi',
#   '1951'),
#  ('Mr. Moon (Carl Smith song)',
#   'https://en.wikipedia.org/wiki/Mr._Moon_(Carl_Smith_song)',
#   '1951'),
#  ('Mixed Emotions (1951 song)',
#   'https://en.wikipedia.org/wiki/Mixed_Emotions_(1951_song)',
#   '1951'),
#  ("Moanin' at Midnight",
#   'https://en.wikipedia.org/wiki/Moanin%27_at_Midnight',
#   '1951'),
#  ("Mockin' Bird Hill",
#   'https://en.wikipedia.org/wiki/Mockin%27_Bird_Hill',
#   '1951'),
#  ("Mom and Dad's Waltz",
#   'https://en.wikipedia.org/wiki/Mom_and_Dad%27s_Waltz',
#   '1951'),
#  ('Morning Side of the Mountain',
#   'https://en.wikipedia.org/wiki/Morning_Side_of_the_Mountain',
#   '1951'),
#  ('Mother Earth (Memphis Slim song)',
#   'https://en.wikipedia.org/wiki/Mother_Earth_(Memphis_Slim_song)',
#   '1951'),
#  ('My Heart Would Know',
#   'https://en.wikipedia.org/wiki/My_Heart_Would_Know',
#   '1951'),
#  ('My Resistance Is Low',
#   'https://en.wikipedia.org/wiki/My_Resistance_Is_Low',
#   '1951'),
#  ('My Truly, Truly Fair',
#   'https://en.wikipedia.org/wiki/My_Truly,_Truly_Fair',
#   '1951'),
#  ('El Negro Zumbón',
#   'https://en.wikipedia.org/wiki/El_Negro_Zumb%C3%B3n',
#   '1951'),
#  ('Night Train (Jimmy Forrest composition)',
#   'https://en.wikipedia.org/wiki/Night_Train_(Jimmy_Forrest_composition)',
#   '1951'),
#  ('Padam, padam...', 'https://en.wikipedia.org/wiki/Padam,_padam...', '1951'),
#  ('Please, Mr. Sun', 'https://en.wikipedia.org/wiki/Please,_Mr._Sun', '1951'),
#  ('Un Poco Loco', 'https://en.wikipedia.org/wiki/Un_Poco_Loco', '1951'),
#  ('Poison Love', 'https://en.wikipedia.org/wiki/Poison_Love', '1951'),
#  ('Quiet Village', 'https://en.wikipedia.org/wiki/Quiet_Village', '1951'),
#  ("Ramblin' Man (Hank Williams song)",
#   'https://en.wikipedia.org/wiki/Ramblin%27_Man_(Hank_Williams_song)',
#   '1951'),
#  ('The Rhumba Boogie',
#   'https://en.wikipedia.org/wiki/The_Rhumba_Boogie',
#   '1951'),
#  ('Rocket 88', 'https://en.wikipedia.org/wiki/Rocket_88', '1951'),
#  ("Rockin' Chair Daddy",
#   'https://en.wikipedia.org/wiki/Rockin%27_Chair_Daddy',
#   '1951'),
#  ('Shall We Dance? (1951 song)',
#   'https://en.wikipedia.org/wiki/Shall_We_Dance%3F_(1951_song)',
#   '1951'),
#  ('Shrimp Boats', 'https://en.wikipedia.org/wiki/Shrimp_Boats', '1951'),
#  ("(It's No) Sin", 'https://en.wikipedia.org/wiki/(It%27s_No)_Sin', '1951'),
# ...
#   '1952'),
#  ('Wonderful Copenhagen',
#   'https://en.wikipedia.org/wiki/Wonderful_Copenhagen',
#   '1952'),
#  ('You Belong to Me (1952 song)',
#   'https://en.wikipedia.org/wiki/You_Belong_to_Me_(1952_song)',
#   '1952'),
#  ('You Better Keep It on Your Mind',
#   'https://en.wikipedia.org/wiki/You_Better_Keep_It_on_Your_Mind',
#   '1952'),
#  ('You Know I Love You (B.B. King song)',
#   'https://en.wikipedia.org/wiki/You_Know_I_Love_You_(B.B._King_song)',
#   '1952'),
#  ('You Win Again (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/You_Win_Again_(Hank_Williams_song)',
#   '1952'),
#  ("Your Cheatin' Heart",
#   'https://en.wikipedia.org/wiki/Your_Cheatin%27_Heart',
#   '1952'),
#  ('Zing a Little Zong',
#   'https://en.wikipedia.org/wiki/Zing_a_Little_Zong',
#   '1952'),
#  ('Accidents Will Happen (Bing Crosby song)',
#   'https://en.wikipedia.org/wiki/Accidents_Will_Happen_(Bing_Crosby_song)',
#   '1950'),
#  ("Adelaide's Lament",
#   'https://en.wikipedia.org/wiki/Adelaide%27s_Lament',
#   '1950'),
#  ('Adoro a mi tierra',
#   'https://en.wikipedia.org/wiki/Adoro_a_mi_tierra',
#   '1950'),
#  ('(Ah, the Apple Trees) When the World Was Young',
#   'https://en.wikipedia.org/wiki/(Ah,_the_Apple_Trees)_When_the_World_Was_Young',
#   '1950'),
#  ('All My Love (Patti Page song)',
#   'https://en.wikipedia.org/wiki/All_My_Love_(Patti_Page_song)',
#   '1950'),
#  ('American Beauty Rose (song)',
#   'https://en.wikipedia.org/wiki/American_Beauty_Rose_(song)',
#   '1950'),
#  ('Anema e core (song)',
#   'https://en.wikipedia.org/wiki/Anema_e_core_(song)',
#   '1950'),
#  ('Anytime, Any Place, Anywhere',
#   'https://en.wikipedia.org/wiki/Anytime,_Any_Place,_Anywhere',
#   '1950'),
#  ("Auf Wiederseh'n, Sweetheart",
#   'https://en.wikipedia.org/wiki/Auf_Wiederseh%27n,_Sweetheart',
#   '1950'),
#  ('Baby, Baby, Baby (Teresa Brewer song)',
#   'https://en.wikipedia.org/wiki/Baby,_Baby,_Baby_(Teresa_Brewer_song)',
#   '1950'),
#  ('Bad, Bad Whiskey',
#   'https://en.wikipedia.org/wiki/Bad,_Bad_Whiskey',
#   '1950'),
#  ("Baião Ca-Room' Pa Pa",
#   'https://en.wikipedia.org/wiki/Bai%C3%A3o_Ca-Room%27_Pa_Pa',
#   '1950'),
#  ('Be My Love', 'https://en.wikipedia.org/wiki/Be_My_Love', '1950'),
#  ('The Best Thing for You (Would Be Me)',
#   'https://en.wikipedia.org/wiki/The_Best_Thing_for_You_(Would_Be_Me)',
#   '1950'),
#  ('Beyond the Sunset (song)',
#   'https://en.wikipedia.org/wiki/Beyond_the_Sunset_(song)',
#   '1950'),
#  ('Big Blue Diamonds',
#   'https://en.wikipedia.org/wiki/Big_Blue_Diamonds',
#   '1950'),
#  ('Birmingham Bounce',
#   'https://en.wikipedia.org/wiki/Birmingham_Bounce',
#   '1950'),
#  ('The Blacksmith Blues',
#   'https://en.wikipedia.org/wiki/The_Blacksmith_Blues',
#   '1950'),
#  ('Blåveispiken', 'https://en.wikipedia.org/wiki/Bl%C3%A5veispiken', '1950'),
#  ('Bloodshot Eyes (song)',
#   'https://en.wikipedia.org/wiki/Bloodshot_Eyes_(song)',
#   '1950'),
#  ('Bloomdido', 'https://en.wikipedia.org/wiki/Bloomdido', '1950'),
#  ('Blue Light Boogie (song)',
#   'https://en.wikipedia.org/wiki/Blue_Light_Boogie_(song)',
#   '1950'),
#  ('Blue Shadows', 'https://en.wikipedia.org/wiki/Blue_Shadows', '1950'),
#  ('Blue Velvet (song)',
#   'https://en.wikipedia.org/wiki/Blue_Velvet_(song)',
#   '1950'),
#  ("Bonaparte's Retreat (Pee Wee King song)",
#   'https://en.wikipedia.org/wiki/Bonaparte%27s_Retreat_(Pee_Wee_King_song)',
#   '1950'),
#  ('Broken Down Merry-Go-Round',
#   'https://en.wikipedia.org/wiki/Broken_Down_Merry-Go-Round',
#   '1950'),
#  ('Buona Sera', 'https://en.wikipedia.org/wiki/Buona_Sera', '1950'),
#  ('A Bushel and a Peck',
#   'https://en.wikipedia.org/wiki/A_Bushel_and_a_Peck',
#   '1950'),
#  ('Can Anyone Explain? (No! No! No!)',
#   'https://en.wikipedia.org/wiki/Can_Anyone_Explain%3F_(No!_No!_No!)',
#   '1950'),
#  ('Chattanoogie Shoe Shine Boy',
#   'https://en.wikipedia.org/wiki/Chattanoogie_Shoe_Shine_Boy',
#   '1950'),
#  ('Chemirocha', 'https://en.wikipedia.org/wiki/Chemirocha', '1950'),
#  ('Cherry Pink (and Apple Blossom White)',
#   'https://en.wikipedia.org/wiki/Cherry_Pink_(and_Apple_Blossom_White)',
#   '1950'),
#  ('Christmas in Killarney',
#   'https://en.wikipedia.org/wiki/Christmas_in_Killarney',
#   '1950'),
#  ('Cincinnati Dancing Pig',
#   'https://en.wikipedia.org/wiki/Cincinnati_Dancing_Pig',
#   '1950'),
#  ('Conception (song)',
#   'https://en.wikipedia.org/wiki/Conception_(song)',
#   '1950'),
#  ('Count Every Star',
#   'https://en.wikipedia.org/wiki/Count_Every_Star',
#   '1950'),
#  ('The Cry of the Wild Goose',
#   'https://en.wikipedia.org/wiki/The_Cry_of_the_Wild_Goose',
#   '1950'),
#  ("Cuddle Buggin' Baby",
#   'https://en.wikipedia.org/wiki/Cuddle_Buggin%27_Baby',
#   '1950'),
#  ("Cupid's Boogie", 'https://en.wikipedia.org/wiki/Cupid%27s_Boogie', '1950'),
#  ('Deal Me a Hand', 'https://en.wikipedia.org/wiki/Deal_Me_a_Hand', '1950'),
#  ('Dearie', 'https://en.wikipedia.org/wiki/Dearie', '1950'),
#  ('Domino (Louis Ferrari and Don Raye song)',
#   'https://en.wikipedia.org/wiki/Domino_(Louis_Ferrari_and_Don_Raye_song)',
#   '1950'),
#  ('Double Crossing Blues',
#   'https://en.wikipedia.org/wiki/Double_Crossing_Blues',
#   '1950'),
#  ('A Dream Is a Wish Your Heart Makes',
#   'https://en.wikipedia.org/wiki/A_Dream_Is_a_Wish_Your_Heart_Makes',
#   '1950'),
#  ('Echoes (1950 song)',
#   'https://en.wikipedia.org/wiki/Echoes_(1950_song)',
#   '1950'),
#  ('Enclosed One Broken Heart',
#   'https://en.wikipedia.org/wiki/Enclosed_One_Broken_Heart',
#   '1950'),
#  ("(Everybody's Waitin' for) The Man with the Bag",
#   'https://en.wikipedia.org/wiki/(Everybody%27s_Waitin%27_for)_The_Man_with_the_Bag',
#   '1950'),
#  ('Faded Love', 'https://en.wikipedia.org/wiki/Faded_Love', '1950'),
#  ('La flor de la canela',
#   'https://en.wikipedia.org/wiki/La_flor_de_la_canela',
#   '1950'),
#  ('Frosty the Snowman',
#   'https://en.wikipedia.org/wiki/Frosty_the_Snowman',
#   '1950'),
#  ('The Funeral (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/The_Funeral_(Hank_Williams_song)',
#   '1950'),
#  ('Take Me in Your Arms (Eddy Arnold song)',
#   'https://en.wikipedia.org/wiki/Take_Me_in_Your_Arms_(Eddy_Arnold_song)',
#   '1950'),
#  ('Take My Love (Frank Sinatra song)',
#   'https://en.wikipedia.org/wiki/Take_My_Love_(Frank_Sinatra_song)',
#   '1950'),
#  ('Take Possession', 'https://en.wikipedia.org/wiki/Take_Possession', '1950'),
#  ('A Teardrop on a Rose',
#   'https://en.wikipedia.org/wiki/A_Teardrop_on_a_Rose',
#   '1950'),
#  ('Teardrops from My Eyes',
#   'https://en.wikipedia.org/wiki/Teardrops_from_My_Eyes',
#   '1950'),
#  ('Tennessee Border No. 2',
#   'https://en.wikipedia.org/wiki/Tennessee_Border_No._2',
#   '1950'),
#  ("There's No Tomorrow",
#   'https://en.wikipedia.org/wiki/There%27s_No_Tomorrow',
#   '1950'),
#  ("They'll Never Take Her Love from Me",
#   'https://en.wikipedia.org/wiki/They%27ll_Never_Take_Her_Love_from_Me',
#   '1950'),
#  ('The Thing (song)',
#   'https://en.wikipedia.org/wiki/The_Thing_(song)',
#   '1950'),
#  ('Throw Your Love My Way',
#   'https://en.wikipedia.org/wiki/Throw_Your_Love_My_Way',
#   '1950'),
#  ("Why Don't You Love Me (Hank Williams song)",
#   'https://en.wikipedia.org/wiki/Why_Don%27t_You_Love_Me_(Hank_Williams_song)',
#   '1950'),
#  ('Why Should I Cry Over You?',
#   'https://en.wikipedia.org/wiki/Why_Should_I_Cry_Over_You%3F',
#   '1950'),
#  ('Why Should We Try Anymore',
#   'https://en.wikipedia.org/wiki/Why_Should_We_Try_Anymore',
#   '1950'),
#  ('Would I Love You (Love You, Love You)',
#   'https://en.wikipedia.org/wiki/Would_I_Love_You_(Love_You,_Love_You)',
#   '1950'),
#  ('Yipsee-I-O', 'https://en.wikipedia.org/wiki/Yipsee-I-O', '1950'),
#  ("You Don't Have to Be a Baby to Cry",
#   'https://en.wikipedia.org/wiki/You_Don%27t_Have_to_Be_a_Baby_to_Cry',
#   '1950'),
#  ("You're All the World to Me",
#   'https://en.wikipedia.org/wiki/You%27re_All_the_World_to_Me',
#   '1950'),
#  ("You're Just in Love",
#   'https://en.wikipedia.org/wiki/You%27re_Just_in_Love',
#   '1950'),
#  ("You've Still Got a Place in My Heart (song)",
#   'https://en.wikipedia.org/wiki/You%27ve_Still_Got_a_Place_in_My_Heart_(song)',
#   '1950'),
#  ('The Gods Were Angry with Me',
#   'https://en.wikipedia.org/wiki/The_Gods_Were_Angry_with_Me',
#   '1950'),
#  ('The Golden Rocket',
#   'https://en.wikipedia.org/wiki/The_Golden_Rocket',
#   '1950'),
#  ('Hard Luck Blues', 'https://en.wikipedia.org/wiki/Hard_Luck_Blues', '1950'),
#  ('Help Me Understand (Hank Williams song)',
#   'https://en.wikipedia.org/wiki/Help_Me_Understand_(Hank_Williams_song)',
#   '1950'),
#  ('Hillbilly Fever', 'https://en.wikipedia.org/wiki/Hillbilly_Fever', '1950'),
#  ('Hold My Hand (1953 song)',
#   'https://en.wikipedia.org/wiki/Hold_My_Hand_(1953_song)',
#   '1950'),
#  ('Hoop-Dee-Doo', 'https://en.wikipedia.org/wiki/Hoop-Dee-Doo', '1950'),
#  ('Hot Rod Race', 'https://en.wikipedia.org/wiki/Hot_Rod_Race', '1950'),
#  ('How Can You Refuse Him Now',
#   'https://en.wikipedia.org/wiki/How_Can_You_Refuse_Him_Now',
#   '1950'),
#  ("Hymne à l'amour",
#   'https://en.wikipedia.org/wiki/Hymne_%C3%A0_l%27amour',
#   '1950'),
#  ('I Almost Lost My Mind',
#   'https://en.wikipedia.org/wiki/I_Almost_Lost_My_Mind',
#   '1950'),
#  ("I Didn't Slip, I Wasn't Pushed, I Fell",
#   'https://en.wikipedia.org/wiki/I_Didn%27t_Slip,_I_Wasn%27t_Pushed,_I_Fell',
#   '1950'),
#  ("I Don't Care if the Sun Don't Shine",
#   'https://en.wikipedia.org/wiki/I_Don%27t_Care_if_the_Sun_Don%27t_Shine',
#   '1950'),
#  ('I Need You So', 'https://en.wikipedia.org/wiki/I_Need_You_So', '1950'),
#  ('I Overlooked an Orchid',
#   'https://en.wikipedia.org/wiki/I_Overlooked_an_Orchid',
#   '1950'),
#  ('I Taut I Taw a Puddy-Tat',
#   'https://en.wikipedia.org/wiki/I_Taut_I_Taw_a_Puddy-Tat',
#   '1950'),
#  ("I'll Never Be Free",
#   'https://en.wikipedia.org/wiki/I%27ll_Never_Be_Free',
#   '1950'),
#  ("I'll Sail My Ship Alone",
#   'https://en.wikipedia.org/wiki/I%27ll_Sail_My_Ship_Alone',
#   '1950'),
#  ("I'm Moving On (Hank Snow song)",
#   'https://en.wikipedia.org/wiki/I%27m_Moving_On_(Hank_Snow_song)',
#   '1950'),
#  ("I've Never Been in Love Before",
#   'https://en.wikipedia.org/wiki/I%27ve_Never_Been_in_Love_Before',
#   '1950'),
#  ("If I Knew You Were Comin' I'd've Baked a Cake",
#   'https://en.wikipedia.org/wiki/If_I_Knew_You_Were_Comin%27_I%27d%27ve_Baked_a_Cake',
#   '1950'),
#  ('If I Were a Bell',
#   'https://en.wikipedia.org/wiki/If_I_Were_a_Bell',
#   '1950'),
#  ("If You've Got the Money I've Got the Time",
#   'https://en.wikipedia.org/wiki/If_You%27ve_Got_the_Money_I%27ve_Got_the_Time',
#   '1950'),
#  ("It's a Lovely Day Today",
#   'https://en.wikipedia.org/wiki/It%27s_a_Lovely_Day_Today',
#   '1950'),
#  ('Jesus Gave Me Water',
#   'https://en.wikipedia.org/wiki/Jesus_Gave_Me_Water',
#   '1950'),
#  ('Kinderhymne', 'https://en.wikipedia.org/wiki/Kinderhymne', '1950'),
#  ('Kisses Sweeter than Wine',
#   'https://en.wikipedia.org/wiki/Kisses_Sweeter_than_Wine',
#   '1950'),
#  ('Last Night I Had the Strangest Dream',
#   'https://en.wikipedia.org/wiki/Last_Night_I_Had_the_Strangest_Dream',
#   '1950'),
#  ("Let's Go to Church (Next Sunday Morning)",
#   'https://en.wikipedia.org/wiki/Let%27s_Go_to_Church_(Next_Sunday_Morning)',
#   '1950'),
#  ('Letters Have No Arms',
#   'https://en.wikipedia.org/wiki/Letters_Have_No_Arms',
#   '1950'),
#  ('Lilac Wine', 'https://en.wikipedia.org/wiki/Lilac_Wine', '1950'),
#  ('Little Angel with the Dirty Face',
#   'https://en.wikipedia.org/wiki/Little_Angel_with_the_Dirty_Face',
#   '1950'),
#  ('Lonesome Traveller',
#   'https://en.wikipedia.org/wiki/Lonesome_Traveller',
#   '1950'),
#  ('Long Gone Lonesome Blues',
#   'https://en.wikipedia.org/wiki/Long_Gone_Lonesome_Blues',
#   '1950'),
#  ('Lovebug Itch', 'https://en.wikipedia.org/wiki/Lovebug_Itch', '1950'),
#  ('May the Good Lord Bless and Keep You',
#   'https://en.wikipedia.org/wiki/May_the_Good_Lord_Bless_and_Keep_You',
#   '1950'),
#  ('Mr. Touchdown, U.S.A.',
#   'https://en.wikipedia.org/wiki/Mr._Touchdown,_U.S.A.',
#   '1950'),
#  ("Mistrustin' Blues",
#   'https://en.wikipedia.org/wiki/Mistrustin%27_Blues',
#   '1950'),
#  ("Moanin' the Blues",
#   'https://en.wikipedia.org/wiki/Moanin%27_the_Blues',
#   '1950'),
#  ('Mona Lisa (Nat King Cole song)',
#   'https://en.wikipedia.org/wiki/Mona_Lisa_(Nat_King_Cole_song)',
#   '1950'),
#  ('My Baby Left Me', 'https://en.wikipedia.org/wiki/My_Baby_Left_Me', '1950'),
#  ('My Heart Cries for You',
#   'https://en.wikipedia.org/wiki/My_Heart_Cries_for_You',
#   '1950'),
#  ('My Son Calls Another Man Daddy',
#   'https://en.wikipedia.org/wiki/My_Son_Calls_Another_Man_Daddy',
#   '1950'),
#  ('National anthem of Mongolia',
#   'https://en.wikipedia.org/wiki/National_anthem_of_Mongolia',
#   '1950'),
#  ('No Other Love (1950 song)',
#   'https://en.wikipedia.org/wiki/No_Other_Love_(1950_song)',
#   '1950'),
#  ('No, No, Joe', 'https://en.wikipedia.org/wiki/No,_No,_Joe', '1950'),
#  ("Nobody's Lonesome for Me",
#   'https://en.wikipedia.org/wiki/Nobody%27s_Lonesome_for_Me',
#   '1950'),
#  ("One Monkey Don't Stop No Show (song)",
#   'https://en.wikipedia.org/wiki/One_Monkey_Don%27t_Stop_No_Show_(song)',
#   '1950'),
#  ('Òran na Cloiche',
#   'https://en.wikipedia.org/wiki/%C3%92ran_na_Cloiche',
#   '1950'),
#  ('Orange Colored Sky',
#   'https://en.wikipedia.org/wiki/Orange_Colored_Sky',
#   '1950'),
#  ('Patricia (1950 song)',
#   'https://en.wikipedia.org/wiki/Patricia_(1950_song)',
#   '1950'),
#  ('Peachtree Street (song)',
#   'https://en.wikipedia.org/wiki/Peachtree_Street_(song)',
#   '1950'),
#  ('Pink Champagne (Joe Liggins song)',
#   'https://en.wikipedia.org/wiki/Pink_Champagne_(Joe_Liggins_song)',
#   '1950'),
#  ('Please Send Me Someone to Love',
#   'https://en.wikipedia.org/wiki/Please_Send_Me_Someone_to_Love',
#   '1950'),
#  ('Quicksilver (song)',
#   'https://en.wikipedia.org/wiki/Quicksilver_(song)',
#   '1950'),
#  ("(Remember Me) I'm the One Who Loves You",
#   'https://en.wikipedia.org/wiki/(Remember_Me)_I%27m_the_One_Who_Loves_You',
#   '1950'),
#  ("Rollin' Stone (Muddy Waters song)",
#   'https://en.wikipedia.org/wiki/Rollin%27_Stone_(Muddy_Waters_song)',
#   '1950'),
#  ('The Roving Kind (song)',
#   'https://en.wikipedia.org/wiki/The_Roving_Kind_(song)',
#   '1950'),
#  ("Sam's Song (song)",
#   'https://en.wikipedia.org/wiki/Sam%27s_Song_(song)',
#   '1950'),
#  ('Shifting Whispering Sands',
#   'https://en.wikipedia.org/wiki/Shifting_Whispering_Sands',
#   '1950'),
#  ('The Shotgun Boogie',
#   'https://en.wikipedia.org/wiki/The_Shotgun_Boogie',
#   '1950'),
#  ('Silver Bells', 'https://en.wikipedia.org/wiki/Silver_Bells', '1950'),
#  ('Simply a Waltz', 'https://en.wikipedia.org/wiki/Simply_a_Waltz', '1950'),
#  ('Sing, Sweet Nightingale',
#   'https://en.wikipedia.org/wiki/Sing,_Sweet_Nightingale',
#   '1950'),
#  ("Sit Down, You're Rockin' the Boat",
#   'https://en.wikipedia.org/wiki/Sit_Down,_You%27re_Rockin%27_the_Boat',
#   '1950'),
#  ('Alice in Wonderland (song)',
#   'https://en.wikipedia.org/wiki/Alice_in_Wonderland_(song)',
#   '1951'),
#  ('All in the Golden Afternoon',
#   'https://en.wikipedia.org/wiki/All_in_the_Golden_Afternoon',
#   '1951'),
#  ('All the Love I Ever Had',
#   'https://en.wikipedia.org/wiki/All_the_Love_I_Ever_Had',
#   '1951'),
#  ('Allentown Jail', 'https://en.wikipedia.org/wiki/Allentown_Jail', '1951'),
#  ('Alone and Forsaken',
#   'https://en.wikipedia.org/wiki/Alone_and_Forsaken',
#   '1951'),
#  ('Always Late with Your Kisses',
#   'https://en.wikipedia.org/wiki/Always_Late_with_Your_Kisses',
#   '1951'),
#  ('And So to Sleep Again',
#   'https://en.wikipedia.org/wiki/And_So_to_Sleep_Again',
#   '1951'),
#  ('Anywhere I Wander',
#   'https://en.wikipedia.org/wiki/Anywhere_I_Wander',
#   '1951'),
#  ('As You Are (Dean Martin song)',
#   'https://en.wikipedia.org/wiki/As_You_Are_(Dean_Martin_song)',
#   '1951'),
#  ('Au Privave', 'https://en.wikipedia.org/wiki/Au_Privave', '1951'),
#  ('Awaara Hoon', 'https://en.wikipedia.org/wiki/Awaara_Hoon', '1951'),
#  ("Baby, We're Really in Love",
#   'https://en.wikipedia.org/wiki/Baby,_We%27re_Really_in_Love',
#   '1951'),
#  ('Bayou Pon Pon', 'https://en.wikipedia.org/wiki/Bayou_Pon_Pon', '1951'),
#  ("Be My Life's Companion",
#   'https://en.wikipedia.org/wiki/Be_My_Life%27s_Companion',
#   '1951'),
#  ('Beautiful Brown Eyes',
#   'https://en.wikipedia.org/wiki/Beautiful_Brown_Eyes',
#   '1951'),
#  ('Bermuda (song)', 'https://en.wikipedia.org/wiki/Bermuda_(song)', '1951'),
#  ('Bessie the Heifer',
#   'https://en.wikipedia.org/wiki/Bessie_the_Heifer',
#   '1951'),
#  ("Birks' Works (composition)",
#   'https://en.wikipedia.org/wiki/Birks%27_Works_(composition)',
#   '1951'),
#  ...]

# %%
pd.set_option('display.max_colwidth', -1)
data = pd.read_csv('decades-MusicBrainz.csv')
data['Clean_Title'] = data['Title'].replace(r'\([^)]*\)', '', regex=True).str.strip()

artist_dict = data.groupby('Title')['Artist'].apply(list).to_dict()
# Out:
# C:\Users\jojuh\AppData\Local\Temp\ipykernel_21236\2802442092.py:1: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                               Title   Artist                 Genres  \
# 118  You Don't Love Me (No, No, No)  Beyoncé  Pop; R&B; Black Music
#
#                                                                                                                                                                                                                                                                                                   Lyric  \
# 118  No no no\nYou don't love me\nAnd I know now\nNo no no\nYou don't love me\nYes, I know now\n'Cause you left me, baby\nAnd I got no place to go now\n\nNo no no\nI'll do anything you say boy\nNo no no\nI'll do anything you say boy\n'Cause if you ask me, baby\nI'll get on my knees and pray boy
#
#      Decade  Year  Popularity        Clean_Title
# 118  1990    1994  205.5       You Don't Love Me

# %%
with open('wiki_songs.pickle', 'rb') as f:
    wiki = pickle.load(f)

df = pd.DataFrame(wiki, columns=['Title','URL','Year'])
df['Clean_Title'] = df['Title'].replace(r'\([^)]*\)', '', regex=True).str.strip()

df = df.merge(data, how='inner', on='Clean_Title')
df['URL_Year'] = df.apply(lambda x: (x['URL'], x['Year_x']), axis=1)

url_dict = df[['Clean_Title','URL','Year_x']].drop_duplicates()[['Clean_Title','URL_Year']].groupby('Clean_Title')['URL_Year'].apply(list).to_dict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 15
#      12 # url_dict = dict(zip(df['URL'], tuple(zip(df['Clean_Title'], df['Year_x']))))
#      13 df['URL_Year'] = df.apply(lambda x: (x['URL'], x['Year_x']), axis=1)
# ---> 15 url_dict = df.groupby(['Clean_Title','URL'], as_index=False).groupby('Clean_Title')['URL_Year'].apply(list).to_dict()
#
# File c:\Users\jojuh\anaconda3\envs\capstone\lib\site-packages\pandas\core\groupby\groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'groupby'

# %%
url_dict = df.drop_duplicates(subset=['Clean_Title','URL','Year_x'])[['Clean_Title','URL_Year']].groupby('Clean_Title')['URL_Year'].apply(list).to_dict()

# %%
url_dict['Until I Die']
# Out:
# [('https://en.wikipedia.org/wiki/Until_I_Die', '2007')]

# %%
# import re
data[data['Clean_Title']=='Halo']

# %%
matches = []

with tqdm(total=len(artist_dict)) as pbar:
    for title, artist in artist_dict.items():
        # print(title)
        urls = url_dict.get(title)
        # print(urls)
        if urls:
            for u, y in urls:
                # print(u)
                page = requests.get(u)
                soup = BeautifulSoup(page.content, 'html.parser') # .find('div', {'id': 'mw-content-text'})
                for a in artist:
                    # print(u)
                    # print('Artist:', a)
                    # print('Trying panel...')
                    if soup.find_all('td', text=re.compile(a)):
                        matches.append((title, a, y))
                        # print('Pane:', title, a, y)
                        break
                    # print('Trying body...')
                    if soup.find_all('p', text=re.compile(a)):
                # if any(r['Artist'] in s for s in soup.strings):
                        matches.append((title, a, y))
                        # print('Body:', title, a, y)
                        break
            
            pbar.update(1)

with open('wiki_matches.pickle', 'wb') as handle:
    pickle.dump(matches, handle)
# Out:
#   5%|▌         | 1530/28941 [55:11<16:28:42,  2.16s/it]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[119], line 17
#      12 soup = BeautifulSoup(page.content, 'html.parser') # .find('div', {'id': 'mw-content-text'})
#      13 for a in artist:
#      14     # print(u)
#      15     # print('Artist:', a)
#      16     # print('Trying panel...')
# ---> 17     if soup.find_all('td', text=re.compile(a)):
#      18         matches.append((title, a, y))
#      19         # print('Pane:', title, a, y)
#
# File c:\Users\jojuh\anaconda3\envs\capstone\lib\re.py:251, in compile(pattern, flags)
#     249 def compile(pattern, flags=0):
#     250     "Compile a regular expression pattern, returning a Pattern object."
# --> 251     return _compile(pattern, flags)
#
# File c:\Users\jojuh\anaconda3\envs\capstone\lib\re.py:303, in _compile(pattern, flags)
#     301 if not sre_compile.isstring(pattern):
#     302     raise TypeError("first argument must be string or compiled pattern")
# --> 303 p = sre_compile.compile(pattern, flags)
#     304 if not (flags & DEBUG):
#     305     if len(_cache) >= _MAXCACHE:
#     306         # Drop the oldest item
#
# File c:\Users\jojuh\anaconda3\envs\capstone\lib\sre_compile.py:788, in compile(p, flags)
#     786 if isstring(p):
#     787     pattern = p
# --> 788     p = sre_parse.parse(p, flags)
#     789 else:
#     790     pattern = None
#
# File c:\Users\jojuh\anaconda3\envs\capstone\lib\sre_parse.py:955, in parse(str, flags, state)
#     952 state.str = str
#     954 try:
# --> 955     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     956 except Verbose:
#     957     # the VERBOSE flag was switched on inside the pattern.  to be
#     958     # on the safe side, we'll parse the whole thing again...
#     959     state = State()
#
# File c:\Users\jojuh\anaconda3\envs\capstone\lib\sre_parse.py:444, in _parse_sub(source, state, verbose, nested)
#     442 start = source.tell()
#     443 while True:
# --> 444     itemsappend(_parse(source, state, verbose, nested + 1,
#     445                        not nested and not items))
#     446     if not sourcematch("|"):
#     447         break
#
# File c:\Users\jojuh\anaconda3\envs\capstone\lib\sre_parse.py:669, in _parse(source, state, verbose, nested, first)
#     667     item = None
#     668 if not item or item[0][0] is AT:
# --> 669     raise source.error("nothing to repeat",
#     670                        source.tell() - here + len(this))
#     671 if item[0][0] in _REPEATCODES:
#     672     raise source.error("multiple repeat",
#     673                        source.tell() - here + len(this))
#
# error: nothing to repeat at position 0

# %%
matches
# Out:
# []

# %%
songs_by_year

# %%
import pandas as pd
df = pd.DataFrame(songs_by_year, columns=['Year','Song','URL'])
len(df[df['URL']=='1950'])
# Out:
# 831

# %%
df[df['URL']=='1950'].to_csv('delete_me.csv')
